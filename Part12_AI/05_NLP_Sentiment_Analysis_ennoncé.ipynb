# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#Load-un-text" data-toc-modified-id="Load-un-text-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load un text</a></span></li><li><span><a href="#Clean" data-toc-modified-id="Clean-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Clean</a></span><ul class="toc-item"><li><span><a href="#Split-phrase-en-mots" data-toc-modified-id="Split-phrase-en-mots-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Split phrase en mots</a></span></li><li><span><a href="#Change-la-ponctuation-en-espace-vide" data-toc-modified-id="Change-la-ponctuation-en-espace-vide-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Change la ponctuation en espace vide</a></span></li><li><span><a href="#Enlève-les-tokens-numérique" data-toc-modified-id="Enlève-les-tokens-numérique-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Enlève les tokens numérique</a></span></li><li><span><a href="#Enlève-les-stop-words-(mots-vides)" data-toc-modified-id="Enlève-les-stop-words-(mots-vides)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Enlève les stop words (mots vides)</a></span></li><li><span><a href="#Enlève-les-mots-de-moins-d'une-lettre" data-toc-modified-id="Enlève-les-mots-de-moins-d'une-lettre-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Enlève les mots de moins d'une lettre</a></span></li><li><span><a href="#Fonction-pour-faire-tout-ça" data-toc-modified-id="Fonction-pour-faire-tout-ça-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Fonction pour faire tout ça</a></span></li></ul></li><li><span><a href="#Créer-un-vocabulaire" data-toc-modified-id="Créer-un-vocabulaire-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Créer un vocabulaire</a></span><ul class="toc-item"><li><span><a href="#Prendre-seulement-ceux-qui-ont-plus-de-2-occurences" data-toc-modified-id="Prendre-seulement-ceux-qui-ont-plus-de-2-occurences-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Prendre seulement ceux qui ont plus de 2 occurences</a></span></li><li><span><a href="#Enregistrer-le-vocabulaire" data-toc-modified-id="Enregistrer-le-vocabulaire-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Enregistrer le vocabulaire</a></span></li></ul></li><li><span><a href="#Convertir-to-bag-of-words" data-toc-modified-id="Convertir-to-bag-of-words-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Convertir to bag of words</a></span><ul class="toc-item"><li><span><a href="#Convertir-chaque-document-en-une-ligne-après-cleaning" data-toc-modified-id="Convertir-chaque-document-en-une-ligne-après-cleaning-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Convertir chaque document en une ligne après cleaning</a></span></li><li><span><a href="#Convertir-cette-ligne-en-représentation-de-bag-of-words" data-toc-modified-id="Convertir-cette-ligne-en-représentation-de-bag-of-words-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Convertir cette ligne en représentation de bag-of-words</a></span></li><li><span><a href="#Tokenisation-du-training-set" data-toc-modified-id="Tokenisation-du-training-set-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Tokenisation du training set</a></span></li><li><span><a href="#Tokenisation-du-test-set" data-toc-modified-id="Tokenisation-du-test-set-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Tokenisation du test set</a></span><ul class="toc-item"><li><span><a href="#Split-training-testing-set" data-toc-modified-id="Split-training-testing-set-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Split training-testing set</a></span></li></ul></li></ul></li><li><span><a href="#Creation-Model" data-toc-modified-id="Creation-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Creation Model</a></span><ul class="toc-item"><li><span><a href="#Test-sur-une-review-d'internet" data-toc-modified-id="Test-sur-une-review-d'internet-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Test sur une review d'internet</a></span></li></ul></li><li><span><a href="#Faire-la-comparaison-entre-les-méthodes" data-toc-modified-id="Faire-la-comparaison-entre-les-méthodes-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Faire la comparaison entre les méthodes</a></span><ul class="toc-item"><li><span><a href="#Prépare-la-fonction-pour-encoder-les-différents-modes" data-toc-modified-id="Prépare-la-fonction-pour-encoder-les-différents-modes-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Prépare la fonction pour encoder les différents modes</a></span></li><li><span><a href="#Prépare-la-fonction-pour-évaluer-les-différents-mode" data-toc-modified-id="Prépare-la-fonction-pour-évaluer-les-différents-mode-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Prépare la fonction pour évaluer les différents mode</a></span></li><li><span><a href="#Load-a-nouveau" data-toc-modified-id="Load-a-nouveau-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Load a nouveau</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Import

# %%
# MLP for the IMDB problem
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import string
import pandas as pd
import numpy as np
from string import punctuation
from os import listdir
from collections import Counter
from keras.preprocessing.text import Tokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/mc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Load un text

# %%
filename = '/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos/cv000_29590.txt'
file = open(filename, 'r')
text = file.read()
print(len(text))
text
# Out:
# 4227
# 'films adapted from comic books have had plenty of success , whether they\'re about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there\'s never really been a comic book like from hell before . \nfor starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid \'80s with a 12-part series called the watchmen . \nto say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd . \nthe book ( or " graphic novel , " if you will ) is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes . \nin other words , don\'t dismiss this film because of its source . \nif you can get past the whole comic book thing , you might find another stumbling block in from hell\'s directors , albert and allen hughes . \ngetting the hughes brothers to direct this seems almost as ludicrous as casting carrot top in , well , anything , but riddle me this : who better to direct a film that\'s set in the ghetto and features really violent street crime than the mad geniuses behind menace ii society ? \nthe ghetto in question is , of course , whitechapel in 1888 london\'s east end . \nit\'s a filthy , sooty place where the whores ( called " unfortunates " ) are starting to get a little nervous about this mysterious psychopath who has been carving through their profession with surgical precision . \nwhen the first stiff turns up , copper peter godley ( robbie coltrane , the world is not enough ) calls in inspector frederick abberline ( johnny depp , blow ) to crack the case . \nabberline , a widower , has prophetic dreams he unsuccessfully tries to quell with copious amounts of absinthe and opium . \nupon arriving in whitechapel , he befriends an unfortunate named mary kelly ( heather graham , say it isn\'t so ) and proceeds to investigate the horribly gruesome crimes that even the police surgeon can\'t stomach . \ni don\'t think anyone needs to be briefed on jack the ripper , so i won\'t go into the particulars here , other than to say moore and campbell have a unique and interesting theory about both the identity of the killer and the reasons he chooses to slay . \nin the comic , they don\'t bother cloaking the identity of the ripper , but screenwriters terry hayes ( vertical limit ) and rafael yglesias ( les mis ? rables ) do a good job of keeping him hidden from viewers until the very end . \nit\'s funny to watch the locals blindly point the finger of blame at jews and indians because , after all , an englishman could never be capable of committing such ghastly acts . \nand from hell\'s ending had me whistling the stonecutters song from the simpsons for days ( " who holds back the electric car/who made steve guttenberg a star ? " ) . \ndon\'t worry - it\'ll all make sense when you see it . \nnow onto from hell\'s appearance : it\'s certainly dark and bleak enough , and it\'s surprising to see how much more it looks like a tim burton film than planet of the apes did ( at times , it seems like sleepy hollow 2 ) . \nthe print i saw wasn\'t completely finished ( both color and music had not been finalized , so no comments about marilyn manson ) , but cinematographer peter deming ( don\'t say a word ) ably captures the dreariness of victorian-era london and helped make the flashy killing scenes remind me of the crazy flashbacks in twin peaks , even though the violence in the film pales in comparison to that in the black-and-white comic . \noscar winner martin childs\' ( shakespeare in love ) production design turns the original prague surroundings into one creepy place . \neven the acting in from hell is solid , with the dreamy depp turning in a typically strong performance and deftly handling a british accent . \nians holm ( joe gould\'s secret ) and richardson ( 102 dalmatians ) log in great supporting roles , but t ...

# %% [markdown]
# ## Clean
# ### Split phrase en mots

# %%
tokens = text.split()
print(tokens)
print(len(tokens))
# Out:
# ['films', 'adapted', 'from', 'comic', 'books', 'have', 'had', 'plenty', 'of', 'success', ',', 'whether', "they're", 'about', 'superheroes', '(', 'batman', ',', 'superman', ',', 'spawn', ')', ',', 'or', 'geared', 'toward', 'kids', '(', 'casper', ')', 'or', 'the', 'arthouse', 'crowd', '(', 'ghost', 'world', ')', ',', 'but', "there's", 'never', 'really', 'been', 'a', 'comic', 'book', 'like', 'from', 'hell', 'before', '.', 'for', 'starters', ',', 'it', 'was', 'created', 'by', 'alan', 'moore', '(', 'and', 'eddie', 'campbell', ')', ',', 'who', 'brought', 'the', 'medium', 'to', 'a', 'whole', 'new', 'level', 'in', 'the', 'mid', "'80s", 'with', 'a', '12-part', 'series', 'called', 'the', 'watchmen', '.', 'to', 'say', 'moore', 'and', 'campbell', 'thoroughly', 'researched', 'the', 'subject', 'of', 'jack', 'the', 'ripper', 'would', 'be', 'like', 'saying', 'michael', 'jackson', 'is', 'starting', 'to', 'look', 'a', 'little', 'odd', '.', 'the', 'book', '(', 'or', '"', 'graphic', 'novel', ',', '"', 'if', 'you', 'will', ')', 'is', 'over', '500', 'pages', 'long', 'and', 'includes', 'nearly', '30', 'more', 'that', 'consist', 'of', 'nothing', 'but', 'footnotes', '.', 'in', 'other', 'words', ',', "don't", 'dismiss', 'this', 'film', 'because', 'of', 'its', 'source', '.', 'if', 'you', 'can', 'get', 'past', 'the', 'whole', 'comic', 'book', 'thing', ',', 'you', 'might', 'find', 'another', 'stumbling', 'block', 'in', 'from', "hell's", 'directors', ',', 'albert', 'and', 'allen', 'hughes', '.', 'getting', 'the', 'hughes', 'brothers', 'to', 'direct', 'this', 'seems', 'almost', 'as', 'ludicrous', 'as', 'casting', 'carrot', 'top', 'in', ',', 'well', ',', 'anything', ',', 'but', 'riddle', 'me', 'this', ':', 'who', 'better', 'to', 'direct', 'a', 'film', "that's", 'set', 'in', 'the', 'ghetto', 'and', 'features', 'really', 'violent', 'street', 'crime', 'than', 'the', 'mad', 'geniuses', 'behind', 'menace', 'ii', 'society', '?', 'the', 'ghetto', 'in', 'question', 'is', ',', 'of', 'course', ',', 'whitechapel', 'in', '1888', "london's", 'east', 'end', '.', "it's", 'a', 'filthy', ',', 'sooty', 'place', 'where', 'the', 'whores', '(', 'called', '"', 'unfortunates', '"', ')', 'are', 'starting', 'to', 'get', 'a', 'little', 'nervous', 'about', 'this', 'mysterious', 'psychopath', 'who', 'has', 'been', 'carving', 'through', 'their', 'profession', 'with', 'surgical', 'precision', '.', 'when', 'the', 'first', 'stiff', 'turns', 'up', ',', 'copper', 'peter', 'godley', '(', 'robbie', 'coltrane', ',', 'the', 'world', 'is', 'not', 'enough', ')', 'calls', 'in', 'inspector', 'frederick', 'abberline', '(', 'johnny', 'depp', ',', 'blow', ')', 'to', 'crack', 'the', 'case', '.', 'abberline', ',', 'a', 'widower', ',', 'has', 'prophetic', 'dreams', 'he', 'unsuccessfully', 'tries', 'to', 'quell', 'with', 'copious', 'amounts', 'of', 'absinthe', 'and', 'opium', '.', 'upon', 'arriving', 'in', 'whitechapel', ',', 'he', 'befriends', 'an', 'unfortunate', 'named', 'mary', 'kelly', '(', 'heather', 'graham', ',', 'say', 'it', "isn't", 'so', ')', 'and', 'proceeds', 'to', 'investigate', 'the', 'horribly', 'gruesome', 'crimes', 'that', 'even', 'the', 'police', 'surgeon', "can't", 'stomach', '.', 'i', "don't", 'think', 'anyone', 'needs', 'to', 'be', 'briefed', 'on', 'jack', 'the', 'ripper', ',', 'so', 'i', "won't", 'go', 'into', 'the', 'particulars', 'here', ',', 'other', 'than', 'to', 'say', 'moore', 'and', 'campbell', 'have', 'a', 'unique', 'and', 'interesting', 'theory', 'about', 'both', 'the', 'identity', 'of', 'the', 'killer', 'and', 'the', 'reasons', 'he', 'chooses', 'to', 'slay', '.', 'in', 'the', 'comic', ',', 'they', "don't", 'bother', 'cloaking', 'the', 'identity', 'of', 'the', 'ripper', ',', 'but', 'screenwriters', 'terry', 'hayes', '(', 'vertical', 'limit', ')', 'and', 'rafael', 'yglesias', '(', 'les', 'mis', '?', 'rables', ')', 'do', 'a', 'good', 'job', 'of', 'keeping', 'him', 'hidden', 'from', 'viewers', 'until', 'the', 'very', 'end', '.', "it's", 'funny', 'to', 'watch', 'the', 'locals',  ...
# 802

# %% [markdown]
# ### Change la ponctuation en espace vide

# %%
table = str.maketrans('', '', string.punctuation)
tokens = [w.translate(table) for w in tokens]
print(len(tokens))
#tokens
# Out:
# 802

# %% [markdown]
# ### Enlève les tokens numérique

# %%
tokens = [word for word in tokens if word.isalpha()]
print(len(tokens))
#tokens
# Out:
# 677

# %% [markdown]
# ### Enlève les stop words (mots vides)

# %%
stop_words = set(stopwords.words('english'))
len(stop_words)
# Out:
# 179

# %%
tokens = [w for w in tokens if not w in stop_words]
#tokens
len(tokens)
# Out:
# 403

# %% [markdown]
# ### Enlève les mots de moins d'une lettre

# %%
tokens = [word for word in tokens if len(word) > 1]
len(tokens)
# Out:
# 402

# %% [markdown]
# ### Fonction pour faire tout ça
# - (1) Créer une fonction pour lire le fichier à partir d'un directory
# - (2) Créer une fonction pour clean le document

# %% [markdown]
# ## Créer un vocabulaire
# ==> Contient le compte de tous les mots de toutes les datas
# - (1) Créer une fonction qui compte le nombre de mots différents dans le texte
# - (2) Créer une fonction qui va lire tous les fichiers ne commençant pas par **cv9** dans un directory donné
# - (3) Afficher le nombre de mot différents dans la totalité des fichiers

# %%
# define vocab
vocab = Counter()
vocab
# Out:
# Counter()

# %%
def add_doc_to_vocab(filename, vocab):
    # load doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # update counts
    vocab.update(tokens)
    

# load all docs in a directory
def process_docs(directory, vocab):
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # add doc to vocab
        add_doc_to_vocab(path, vocab)

# %%
process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab)
process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab)

# %%
print(len(vocab))
# Out:
# 44276

# %% [markdown]
# ### Prendre seulement ceux qui ont plus de 2 occurences
# - (1) Faites ce clean (mot appraissant plus de deux fois)
# - (2) Printer le nombre de mot supprimé et le nombre de mot total réstant

# %%
# keep tokens with a min occurrence
min_occurane = 2
tokens = [k for k,c in vocab.items() if c >= min_occurane]
print(len(tokens))
# Out:
# 25767

# %% [markdown]
# ### Enregistrer le vocabulaire

# %%
# save list to file
def save_list(lines, filename):
    # convert lines to a single blob of text
    data = '\n'.join(lines)
    # open file
    file = open(filename, 'w')
    # write text
    file.write(data)
    # close file
    file.close()

# save tokens to a vocabulary file
save_list(tokens, 'vocab1.txt')

# %% [markdown]
# ## Convertir to bag of words
# Ici chaque document sera sous forme d'un vecteur de représentation de longueur du vocabulaire (22767 si on supprime les mots n'apparraissant unique plus de 2 fois)
# Il faut donc d'abords:
# - (1) Convertir chaque document en une ligne après cleaning
# - (2) Convertir cette ligne en représentation de bag-of-words
#
# ### Convertir chaque document en une ligne après cleaning

# %%
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
    # load the doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [w for w in tokens if w in vocab]
    return ' '.join(tokens)


# load all docs in a directory
def process_docs(directory, vocab):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# %%
vocab_filename = 'vocab1.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
vocab
# Out:
# {'brainless',
#  'kates',
#  'setback',
#  'nero',
#  'dishes',
#  'toyed',
#  'fierstein',
#  'offers',
#  'accentuate',
#  'travesty',
#  'condemn',
#  'supercop',
#  'fairness',
#  'centurys',
#  'encounter',
#  'pintsized',
#  'jeroen',
#  'pickles',
#  'bane',
#  'advisors',
#  'gather',
#  'november',
#  'copland',
#  'bankrupt',
#  'attends',
#  'dewitt',
#  'suspiciously',
#  'depressed',
#  'evoking',
#  'swims',
#  'five',
#  'sitcomish',
#  'aaliyah',
#  'unfathomable',
#  'stifling',
#  'lynched',
#  'dealings',
#  'songcatcher',
#  'misconstrued',
#  'rican',
#  'observant',
#  'heavyhanded',
#  'embroiled',
#  'payload',
#  'leonard',
#  'depending',
#  'merely',
#  'recklessness',
#  'consistently',
#  'shall',
#  'tasted',
#  'pillpoppin',
#  'ol',
#  'schumacher',
#  'nothin',
#  'condemnation',
#  'flexibility',
#  'winnfield',
#  'wrongs',
#  'help',
#  'onwards',
#  'rewards',
#  'neary',
#  'jagger',
#  'ravenous',
#  'memphis',
#  'reissue',
#  'honeywell',
#  'patron',
#  'investment',
#  'prolific',
#  'signaling',
#  'ade',
#  'sampling',
#  'doa',
#  'indoctrinated',
#  'nearconstant',
#  'nntphub',
#  'devoid',
#  'manifesting',
#  'anonymity',
#  'edition',
#  'straighten',
#  'tangent',
#  'tom',
#  'criticisms',
#  'bartleby',
#  'mountain',
#  'staggers',
#  'worldweary',
#  'unsettled',
#  'trader',
#  'recruit',
#  'alejandro',
#  'harrington',
#  'computergenerated',
#  'parsee',
#  'voodoo',
#  'arrange',
#  'confront',
#  'element',
#  'urgency',
#  'grossly',
#  'edges',
#  'fuckin',
#  'shes',
#  'willis',
#  'herring',
#  'pammy',
#  'doofy',
#  'furry',
#  'drab',
#  'veronicas',
#  'thy',
#  'miscalculated',
#  'messages',
#  'noticing',
#  'maples',
#  'river',
#  'vandamme',
#  'groomed',
#  'slay',
#  'evenings',
#  'belushi',
#  'cleaner',
#  'handguns',
#  'unleashes',
#  'anand',
#  'unattractive',
#  'dellaplanes',
#  'chicks',
#  'jos',
#  'priscilla',
#  'lillard',
#  'branagh',
#  'kaurism',
#  'vibrate',
#  'oneliner',
#  'lipnicki',
#  'foreboding',
#  'splits',
#  'threehour',
#  'ironies',
#  'pads',
#  'cigarette',
#  'sides',
#  'repetitious',
#  'boating',
#  'sanders',
#  'degeneration',
#  'singlehandedly',
#  'zeros',
#  'reclaim',
#  'und',
#  'jenkins',
#  'requiem',
#  'champ',
#  'john',
#  'walled',
#  'symphony',
#  'sissy',
#  'patients',
#  'cloudy',
#  'individually',
#  'patch',
#  'mississippi',
#  'antisemitic',
#  'cabaret',
#  'egodriven',
#  'dropping',
#  'emerson',
#  'glorify',
#  'appointed',
#  'daleks',
#  'diminishing',
#  'perlman',
#  'topsyturvy',
#  'commission',
#  'loved',
#  'reviewer',
#  'shocking',
#  'quote',
#  'episodes',
#  'superblyrealized',
#  'turkey',
#  'requesting',
#  'stride',
#  'failsafe',
#  'drops',
#  'plainly',
#  'swan',
#  'resurrected',
#  'pelt',
#  'wrestle',
#  'hamm',
#  'bashing',
#  'courier',
#  'characterize',
#  'cheered',
#  'cabbie',
#  'union',
#  'selling',
#  'evars',
#  'understated',
#  'croatia',
#  'oconnell',
#  'upbeat',
#  'onenight',
#  'lackey',
#  'desouza',
#  'exploded',
#  'splattering',
#  'completly',
#  'timing',
#  'metal',
#  'du',
#  'birth',
#  'working',
#  'anyone',
#  'disturbs',
#  'bought',
#  'joans',
#  'camouflage',
#  'garden',
#  'ming',
#  'officials',
#  'stupid',
#  'dude',
#  'tools',
#  'finale',
#  'accompanying',
#  'elementary',
#  'authored',
#  'mulans',
#  'abilities',
#  'caring',
#  'hardearned',
#  'comeback',
#  'jolt',
#  'redemptive',
#  'established',
#  'omnipresent',
#  'rank',
#  'llama',
#  'inspired',
#  'exclamation',
#  'incapacitated',
#  'depps',
#  'bevy',
#  'alchemy',
#  'house',
#  'accuses',
#  'potter',
#  'disarmingly',
#  'pocahontas',
#  'dodge',
#  'rupert',
#  'innumerable',
#  'wesley',
#  'splendidly',
#  'goldbergs',
#  'aux',
#  'unclothed',
#  'befriends',
#  'nino',
#  'ringwalds',
#  'effected',
#  'fillings',
#  'degenerative',
#  'download',
#  'abolitionists',
#  'foes',
#  'actress',
#  'fitts',
#  'flirtations',
#  'nearing',
#  'orientation',
#  'johnny',
#  'shaping',
#  'projects',
#  'bakula',
#  'nuances',
#  'um',
#  'princeton',
#  'surge',
#  'miscalculation',
#  'lack',
#  'tension',
#  'booming',
#  'mounts',
#  'mallory',
#  'braeden',
#  'disillusionment',
#  'proposed',
#  'patrol',
#  'backside',
#  'hamill',
#  'veteran',
#  'hutchinson',
#  'prescription',
#  'fired',
#  'nest',
#  'abundant',
#  'imitation',
#  'curses',
#  'cams',
#  'aphrodite',
#  'relies',
#  'churn',
#  'ultimately',
#  'loading',
#  'saucers',
#  'cheapjack',
#  'mack',
#  'butler',
#  'floor',
#  'total',
#  'masterpiece',
#  'numbers',
#  'malkovichs',
#  'plummeting',
#  'anchors',
#  'induced',
#  'ritchie',
#  'young',
#  'sweeney',
#  'striving',
#  'dissolves',
#  'central',
#  'mush',
#  'inhabitant',
#  'undetectable',
#  'penultimate',
#  'bouncer',
#  'outbursts',
#  'itami',
#  'tinier',
#  'tobacco',
#  'guillermo',
#  'samples',
#  'islands',
#  'moody',
#  'selfrespect',
#  'walters',
#  'hilarious',
#  'shifty',
#  'flamm',
#  'interviewer',
#  'borrow',
#  'avery',
#  'satisfy',
#  'sordid',
#  'trailera',
#  'crafted',
#  'demanded',
#  'manner',
#  'goon',
#  'vcr',
#  'circular',
#  'alist',
#  'approaches',
#  'mib',
#  'psyche',
#  'chrysler',
#  'moviegoers',
#  'insular',
#  'stray',
#  'javier',
#  'smartly',
#  'alignment',
#  'metro',
#  'jesus',
#  'excrutiatingly',
#  'cohorts',
#  'transmission',
#  'woodenly',
#  'noteworthy',
#  'valleys',
#  'hallway',
#  'unenjoyable',
#  'fraser',
#  'muppets',
#  'mutual',
#  'gained',
#  'marianne',
#  'erickson',
#  'fulfills',
#  'fiorentino',
#  'catalog',
#  'ricci',
#  'hustling',
#  'trois',
#  'wizardry',
#  'folk',
#  'detect',
#  'kinda',
#  'port',
#  'youths',
#  'minnie',
#  'straightforward',
#  'frequents',
#  'blowout',
#  'transportation',
#  'peaceful',
#  'measurements',
#  'reon',
#  'inkpot',
#  'princess',
#  'studios',
#  'undercover',
#  'oppose',
#  'contrasting',
#  'deedle',
#  'comely',
#  'protruding',
#  'crimson',
#  'disappears',
#  'leather',
#  'newt',
#  'tromping',
#  'squirminducing',
#  'acquit',
#  'wunderkind',
#  'treaty',
#  'vote',
#  'fascinating',
#  'bailed',
#  'dansons',
#  'forsythe',
#  'grandparents',
#  'financially',
#  'suicides',
#  'wears',
#  'sprinkled',
#  'capitalize',
#  'guinea',
#  'aldas',
#  'minimally',
#  'ghouls',
#  'dupe',
#  'anakins',
#  'shady',
#  'duncan',
#  'selfishness',
#  'race',
#  'foray',
#  'robinsons',
#  'riley',
#  'derelict',
#  'neonazi',
#  'marlo',
#  'relaxing',
#  'point',
#  'bujold',
#  'rowlands',
#  'ritualistic',
#  'alienates',
#  'tracks',
#  'deposit',
#  'pronouncements',
#  'carsex',
#  'hangeron',
#  'nightly',
#  'arthur',
#  'terminated',
#  'crescendo',
#  'headless',
#  'blip',
#  'sasha',
#  'schemes',
#  'ladders',
#  'meter',
#  'proportions',
#  'slogans',
#  'blocks',
#  'januarys',
#  'danica',
#  'ulee',
#  'disgustingly',
#  'jack',
#  'barroom',
#  'tieins',
#  'locate',
#  'teach',
#  'cary',
#  'chart',
#  'promised',
#  'continues',
#  'unsatisfied',
#  'rush',
#  'calm',
#  'ips',
#  'horde',
#  'gwen',
#  'misfortunes',
#  'veterans',
#  'compendium',
#  'qualms',
#  'lackluster',
#  'spoken',
#  'credit',
#  'palm',
#  'pivot',
#  'devils',
#  'vicepresident',
#  'beauties',
#  'equally',
#  'leders',
#  'ventura',
#  'newton',
#  'tatooed',
#  'overseeing',
#  'noseworthy',
#  'pratfalls',
#  'flashbacks',
#  'projection',
#  'county',
#  'researchers',
#  'def',
#  'unfunny',
#  'xmen',
#  'competition',
#  'latifa',
#  'terminators',
#  'earthshattering',
#  'confessing',
#  'stronger',
#  'larter',
#  'drugaddict',
#  'cockney',
#  'leyland',
#  'forgiveness',
#  'horsing',
#  'irrepressible',
#  'pods',
#  'valiantly',
#  'charmless',
#  'notion',
#  'slope',
#  'deceiver',
#  'end',
#  'quarter',
#  'devices',
#  'guiltypleasure',
#  'birdcage',
#  'raped',
#  'kimberly',
#  'slambang',
#  'humvee',
#  'revival',
#  'ranch',
#  'vindication',
#  'moss',
#  'sermon',
#  'holloway',
#  'jump',
#  'updrafts',
#  'trade',
#  'left',
#  'lewis',
#  'devise',
#  'salary',
#  'paroled',
#  'hydraulic',
#  'chronicling',
#  'darius',
#  'protectors',
#  'georges',
#  'reappears',
#  'cheating',
#  'barrier',
#  'bregman',
#  'grownups',
#  'satisfactorily',
#  'beaumarchais',
#  'moviegoing',
#  'solid',
#  'newcomers',
#  'bolster',
#  'screening',
#  'confinement',
#  'laughton',
#  'tunney',
#  'rex',
#  'dutton',
#  'feeding',
#  'endured',
#  'actively',
#  'pauly',
#  'suffer',
#  'matron',
#  'quickflash',
#  'woodbine',
#  'jawed',
#  'palatable',
#  'dawes',
#  'problematic',
#  'maniac',
#  'levar',
#  'editor',
#  'manifest',
#  'antidote',
#  'defensive',
#  'sarandon',
#  'identical',
#  'judi',
#  'honorable',
#  'shanyu',
#  'dormant',
#  'adefarasin',
#  'rb',
#  'outworlds',
#  'neatly',
#  'edie',
#  'dope',
#  'makeout',
#  'priority',
#  'nono',
#  'stays',
#  'bach',
#  'restauranteur',
#  'spins',
#  'selfdefense',
#  'comparable',
#  'wanton',
#  'grooving',
#  'housewife',
#  'rameses',
#  'muses',
#  'bouts',
#  'theyll',
#  'ignores',
#  'zemeckiss',
#  'screw',
#  'overdecorated',
#  'bedside',
#  'blind',
#  'www',
#  'wifes',
#  'amis',
#  'cassandras',
#  'schizophrenia',
#  'vader',
#  'thrash',
#  'tongueincheek',
#  'franciss',
#  'glimcher',
#  'trimming',
#  'lever',
#  'jericho',
#  'perez',
#  'satisfied',
#  'franks',
#  'going',
#  'weve',
#  'eblock',
#  'valli',
#  'illicit',
#  'havent',
#  'underscores',
#  'quigon',
#  'lonergan',
#  'flare',
#  'rights',
#  'frustrate',
#  'circle',
#  'incest',
#  'intrusion',
#  'fittingly',
#  'aaa',
#  'conceived',
#  'matteroffactly',
#  'han',
#  'incestuous',
#  'film',
#  'unmatched',
#  'insurrections',
#  'representing',
#  'meddled',
#  'reclusive',
#  'willard',
#  'blankets',
#  'likes',
#  'intermittent',
#  'braindead',
#  'leverage',
#  'longstreet',
#  'subplot',
#  'derives',
#  'coercion',
#  'splendor',
#  'davies',
#  'nightmares',
#  'delicatessen',
#  'pose',
#  'waving',
#  'goriest',
#  'lap',
#  'leuchters',
#  'cutesy',
#  'overtakes',
#  'diluted',
#  'plotting',
#  'sections',
#  'rhapsody',
#  'wounds',
#  'concentrates',
#  'came',
#  'origins',
#  'brighten',
#  'viceversa',
#  'gnosis',
#  'mod',
#  'sharp',
#  'mosquito',
#  'compound',
#  'mobs',
#  'hedaya',
#  'relied',
#  'parlay',
#  'orlocks',
#  'stamper',
#  'frederic',
#  'commented',
#  'stahl',
#  'marriages',
#  'accumulated',
#  'careening',
#  'bursts',
#  'clubs',
#  'demonstrating',
#  'bridge',
#  'captivating',
#  'skill',
#  'seem',
#  'nookey',
#  'hallucination',
#  'miyamoto',
#  'impressive',
#  'enraged',
#  'ferguson',
#  'acrimonious',
#  'viannes',
#  'selfabsorbed',
#  'kudrow',
#  'thumbs',
#  'alienating',
#  'likable',
#  'radiate',
#  'squabble',
#  'sevigny',
#  'endowed',
#  'preferring',
#  'christophers',
#  'packs',
#  'deeper',
#  'purpose',
#  'feces',
#  'gullette',
#  'bargains',
#  'cheerful',
#  'televisions',
#  'sagemiller',
#  'grime',
#  'ethel',
#  'butterfly',
#  'attributes',
#  'clarks',
#  'maximilian',
#  'soontobe',
#  'poisonous',
#  'personal',
#  'obi',
#  'outworld',
#  'janet',
#  'busybody',
#  'reinforced',
#  'advice',
#  'eightyearold',
#  'initiates',
#  'dalmatians',
#  'cheezy',
#  'hitching',
#  'thine',
#  'sands',
#  'arquettes',
#  'amends',
#  'press',
#  'realise',
#  'sports',
#  'offscreen',
#  'wee',
#  'flows',
#  'blurry',
#  'wits',
#  'premarital',
#  'construction',
#  'abode',
#  'token',
#  'smirking',
#  'startlingly',
#  'trachtenberg',
#  'gap',
#  'fearless',
#  'crawls',
#  'reside',
#  'slides',
#  'civilized',
#  'supporting',
#  'interested',
#  'prophesies',
#  'iguana',
#  'touched',
#  'bitterly',
#  'seethrough',
#  'dissatisfaction',
#  'reduce',
#  'richer',
#  'etched',
#  'matildas',
#  'eyelashes',
#  'cocktail',
#  'plugs',
#  'wonka',
#  'commences',
#  'peep',
#  'laptops',
#  'tbwp',
#  'story',
#  'typewriter',
#  'sylvie',
#  'richies',
#  'guarantees',
#  'mimi',
#  'smiled',
#  'navaz',
#  'professionals',
#  'unworthy',
#  'disarm',
#  'greatlooking',
#  'tattoos',
#  'abortion',
#  'tranquil',
#  'vladimir',
#  'awareness',
#  'dench',
#  'imbecile',
#  'iowa',
#  'gallery',
#  'refinery',
#  'couldve',
#  'unfairly',
#  'blanchette',
#  'distracts',
#  'sewer',
#  'triumphantly',
#  'linger',
#  'improv',
#  'cleansing',
#  'sadist',
#  'typecasted',
#  'ummm',
#  'location',
#  'stifled',
#  'habit',
#  'heart',
#  'yuppie',
#  'nonexistent',
#  'patrols',
#  'assortment',
#  'merchants',
#  'claudius',
#  'greenlit',
#  'sm',
#  'variations',
#  'yarn',
#  'barges',
#  'scheming',
#  'gwtw',
#  'sgt',
#  'appealing',
#  'vars',
#  'magnifying',
#  'henn',
#  'kross',
#  'intentioned',
#  'delightfully',
#  'melissa',
#  'recapture',
#  'notoriety',
#  'concussion',
#  'debate',
#  'cruising',
#  'feuds',
#  'jettison',
#  'cluttered',
#  'bomber',
#  'hyperdrive',
#  'stifler',
#  'seduces',
#  'pleads',
#  'smarter',
#  'fund',
#  'housekeeping',
#  'kronk',
#  'feldman',
#  'robo',
#  'inflection',
#  'test',
#  'squandering',
#  'rapist',
#  'samurai',
#  'spoof',
#  'allen',
#  'bahamas',
#  'textures',
#  'carver',
#  'malevolent',
#  'mall',
#  'sad',
#  'prospector',
#  'fiendish',
#  'aww',
#  'cylinders',
#  'chummy',
#  'constrained',
#  'flashy',
#  'elicits',
#  'narrating',
#  'olden',
#  'variant',
#  'greased',
#  'hold',
#  'mugging',
#  'taking',
#  'thugs',
#  'grizzly',
#  'rope',
#  'demornay',
#  'accountant',
#  'morses',
#  'dealing',
#  'chaplin',
#  'discovering',
#  'knox',
#  'francies',
#  'sperm',
#  'wilhelm',
#  'saw',
#  'paul',
#  'creativity',
#  'montgomery',
#  'bergmans',
#  'insipid',
#  'amiel',
#  'ally',
#  'verify',
#  'guntoting',
#  'prove',
#  'identifiable',
#  'operatic',
#  'otter',
#  'bierko',
#  'note',
#  'etc',
#  'roldan',
#  'denominator',
#  'boulder',
#  'smuggle',
#  'bout',
#  'phil',
#  'hallways',
#  'murray',
#  'seriess',
#  'pilot',
#  'second',
#  'juices',
#  'utah',
#  'bountiful',
#  'minus',
#  'goldsmith',
#  'comprehend',
#  'jewels',
#  'xavier',
#  'predilection',
#  'saintly',
#  'myra',
#  'miracle',
#  'beast',
#  'thorny',
#  'salvation',
#  'outandout',
#  'anarchic',
#  'bottles',
#  'moby',
#  'bears',
#  'settling',
#  'rec',
#  'improve',
#  'exchanges',
#  ...}

# %%
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab)
# summarize what we have
print(len(positive_lines), len(negative_lines))
# Out:
# 900 900

# %% [markdown]
# ### Convertir cette ligne en représentation de bag-of-words
# Il est possibile d'utiliser l'API de Keras pour transformer les phrases en vecteurs. Il suffit simplement d'entraîner (fit) nos training review et d'indiquer le mode, il en existe plusieurs:
# - freq
# - count
# - tdif
# - binary

# %%
tokenizer.fit_on_texts(docs)

# %%
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = positive_lines + negative_lines
tokenizer.fit_on_texts(docs)

# %%
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
Xtrain.shape#[0]
# Out:
# (1800, 25768)

# %%
tokenizer.texts_to_matrix(docs, mode='freq').shape
# Out:
# (1800, 25768)

# %% [markdown]
# Il faut modifier notre fonction process_docs afin qu'elle prenne en compte si nous sommes dans le training ou le test set. L'objectif est d'éviter le data leakage et d'obtenir des informations sur notre test set alors que l'on doit rester le plus naïf possible

# %%
# load all docs in a directory
def process_docs(directory, vocab, is_trian):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if is_trian and filename.startswith('cv9'):
            continue
        if not is_trian and not filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# %% [markdown]
# ### Tokenisation du training set

# %%
vocab_filename = 'vocab1.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, True)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, True)
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = negative_lines + positive_lines
tokenizer.fit_on_texts(docs)
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')

tokenizer.fit_on_texts(docs)
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
pd.DataFrame(Xtrain[0]).plot()
pd.DataFrame(Xtrain[1]).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Tokenisation du test set

# %%
vocab_filename = 'vocab1.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, False)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, False)

# fit the tokenizer on the documents
docs = negative_lines + positive_lines
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')

# %% [markdown]
# #### Split training-testing set
# ==> test set soit modifié en fonction du training
# ==> éviter le data leakage

# %% [markdown]
# ## Creation Model
# Il faut d'abords créer la target qui est assez facile 1 pour positive et 0 pour négative pour le training et test set
# - (1) Créer la target (ytrain et ytest) avec 0 pour négative et 1 pour positive
# - (2) Créer un réseau de neurones avec comme input shape la taille du vecteur de chaque input

# %% [markdown]
# ### Test sur une review d'internet
# - (1) Chercher une review de filme sur internet ou écrivez en une, puis tester votre algo sur cette review

# %% [markdown]
# ## Faire la comparaison entre les méthodes
# - Binary (chaque mot est présent ou absent 1, 0)
# - Count (compter le nombre de mots)
# - tfidf (fréquence du mot et les mots communs entre chaque documents sont pénalisé)
# - fréquence
#
# ### Prépare la fonction pour encoder les différents modes

# %% [markdown]
# ### Prépare la fonction pour évaluer les différents mode

# %% [markdown]
# ### Load a nouveau
