# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#Load-un-text" data-toc-modified-id="Load-un-text-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load un text</a></span></li><li><span><a href="#Clean" data-toc-modified-id="Clean-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Clean</a></span><ul class="toc-item"><li><span><a href="#Split-phrase-en-mots" data-toc-modified-id="Split-phrase-en-mots-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Split phrase en mots</a></span></li><li><span><a href="#Change-la-ponctuation-en-espace-vide" data-toc-modified-id="Change-la-ponctuation-en-espace-vide-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Change la ponctuation en espace vide</a></span></li><li><span><a href="#Enlève-les-tokens-non-numérique" data-toc-modified-id="Enlève-les-tokens-non-numérique-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Enlève les tokens non numérique</a></span></li><li><span><a href="#Enlève-les-stop-words-(mots-vides)" data-toc-modified-id="Enlève-les-stop-words-(mots-vides)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Enlève les stop words (mots vides)</a></span></li><li><span><a href="#Enlève-les-mots-de-moins-d'une-lettre" data-toc-modified-id="Enlève-les-mots-de-moins-d'une-lettre-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Enlève les mots de moins d'une lettre</a></span></li><li><span><a href="#Fonction-pour-faire-tout-ça" data-toc-modified-id="Fonction-pour-faire-tout-ça-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Fonction pour faire tout ça</a></span></li></ul></li><li><span><a href="#Créer-un-vocabulaire" data-toc-modified-id="Créer-un-vocabulaire-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Créer un vocabulaire</a></span><ul class="toc-item"><li><span><a href="#Prendre-seulement-ceux-qui-ont-plus-de-2-occurences" data-toc-modified-id="Prendre-seulement-ceux-qui-ont-plus-de-2-occurences-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Prendre seulement ceux qui ont plus de 2 occurences</a></span></li><li><span><a href="#Enregistrer-le-vocabulaire" data-toc-modified-id="Enregistrer-le-vocabulaire-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Enregistrer le vocabulaire</a></span></li></ul></li><li><span><a href="#Convertir-to-bag-of-words" data-toc-modified-id="Convertir-to-bag-of-words-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Convertir to bag of words</a></span></li><li><span><a href="#Tokenizer" data-toc-modified-id="Tokenizer-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Tokenizer</a></span></li><li><span><a href="#Creation-Model" data-toc-modified-id="Creation-Model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Creation Model</a></span></li></ul></div>

# %% [markdown]
# ## Import

# %%
# MLP for the IMDB problem
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
import nltk
from nltk.corpus import stopwords
import string
import numpy as np
from string import punctuation
from os import listdir
from collections import Counter
from keras.preprocessing.text import Tokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/mc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Load un text

# %%
filename = '/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos/cv000_29590.txt'
file = open(filename, 'r')
text = file.read()
text
# Out:
# 'films adapted from comic books have had plenty of success , whether they\'re about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there\'s never really been a comic book like from hell before . \nfor starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid \'80s with a 12-part series called the watchmen . \nto say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd . \nthe book ( or " graphic novel , " if you will ) is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes . \nin other words , don\'t dismiss this film because of its source . \nif you can get past the whole comic book thing , you might find another stumbling block in from hell\'s directors , albert and allen hughes . \ngetting the hughes brothers to direct this seems almost as ludicrous as casting carrot top in , well , anything , but riddle me this : who better to direct a film that\'s set in the ghetto and features really violent street crime than the mad geniuses behind menace ii society ? \nthe ghetto in question is , of course , whitechapel in 1888 london\'s east end . \nit\'s a filthy , sooty place where the whores ( called " unfortunates " ) are starting to get a little nervous about this mysterious psychopath who has been carving through their profession with surgical precision . \nwhen the first stiff turns up , copper peter godley ( robbie coltrane , the world is not enough ) calls in inspector frederick abberline ( johnny depp , blow ) to crack the case . \nabberline , a widower , has prophetic dreams he unsuccessfully tries to quell with copious amounts of absinthe and opium . \nupon arriving in whitechapel , he befriends an unfortunate named mary kelly ( heather graham , say it isn\'t so ) and proceeds to investigate the horribly gruesome crimes that even the police surgeon can\'t stomach . \ni don\'t think anyone needs to be briefed on jack the ripper , so i won\'t go into the particulars here , other than to say moore and campbell have a unique and interesting theory about both the identity of the killer and the reasons he chooses to slay . \nin the comic , they don\'t bother cloaking the identity of the ripper , but screenwriters terry hayes ( vertical limit ) and rafael yglesias ( les mis ? rables ) do a good job of keeping him hidden from viewers until the very end . \nit\'s funny to watch the locals blindly point the finger of blame at jews and indians because , after all , an englishman could never be capable of committing such ghastly acts . \nand from hell\'s ending had me whistling the stonecutters song from the simpsons for days ( " who holds back the electric car/who made steve guttenberg a star ? " ) . \ndon\'t worry - it\'ll all make sense when you see it . \nnow onto from hell\'s appearance : it\'s certainly dark and bleak enough , and it\'s surprising to see how much more it looks like a tim burton film than planet of the apes did ( at times , it seems like sleepy hollow 2 ) . \nthe print i saw wasn\'t completely finished ( both color and music had not been finalized , so no comments about marilyn manson ) , but cinematographer peter deming ( don\'t say a word ) ably captures the dreariness of victorian-era london and helped make the flashy killing scenes remind me of the crazy flashbacks in twin peaks , even though the violence in the film pales in comparison to that in the black-and-white comic . \noscar winner martin childs\' ( shakespeare in love ) production design turns the original prague surroundings into one creepy place . \neven the acting in from hell is solid , with the dreamy depp turning in a typically strong performance and deftly handling a british accent . \nians holm ( joe gould\'s secret ) and richardson ( 102 dalmatians ) log in great supporting roles , but t ...

# %% [markdown]
# ## Clean
# ### Split phrase en mots

# %%
tokens = text.split()
print(tokens)
print(len(tokens))
# Out:
# ['films', 'adapted', 'from', 'comic', 'books', 'have', 'had', 'plenty', 'of', 'success', ',', 'whether', "they're", 'about', 'superheroes', '(', 'batman', ',', 'superman', ',', 'spawn', ')', ',', 'or', 'geared', 'toward', 'kids', '(', 'casper', ')', 'or', 'the', 'arthouse', 'crowd', '(', 'ghost', 'world', ')', ',', 'but', "there's", 'never', 'really', 'been', 'a', 'comic', 'book', 'like', 'from', 'hell', 'before', '.', 'for', 'starters', ',', 'it', 'was', 'created', 'by', 'alan', 'moore', '(', 'and', 'eddie', 'campbell', ')', ',', 'who', 'brought', 'the', 'medium', 'to', 'a', 'whole', 'new', 'level', 'in', 'the', 'mid', "'80s", 'with', 'a', '12-part', 'series', 'called', 'the', 'watchmen', '.', 'to', 'say', 'moore', 'and', 'campbell', 'thoroughly', 'researched', 'the', 'subject', 'of', 'jack', 'the', 'ripper', 'would', 'be', 'like', 'saying', 'michael', 'jackson', 'is', 'starting', 'to', 'look', 'a', 'little', 'odd', '.', 'the', 'book', '(', 'or', '"', 'graphic', 'novel', ',', '"', 'if', 'you', 'will', ')', 'is', 'over', '500', 'pages', 'long', 'and', 'includes', 'nearly', '30', 'more', 'that', 'consist', 'of', 'nothing', 'but', 'footnotes', '.', 'in', 'other', 'words', ',', "don't", 'dismiss', 'this', 'film', 'because', 'of', 'its', 'source', '.', 'if', 'you', 'can', 'get', 'past', 'the', 'whole', 'comic', 'book', 'thing', ',', 'you', 'might', 'find', 'another', 'stumbling', 'block', 'in', 'from', "hell's", 'directors', ',', 'albert', 'and', 'allen', 'hughes', '.', 'getting', 'the', 'hughes', 'brothers', 'to', 'direct', 'this', 'seems', 'almost', 'as', 'ludicrous', 'as', 'casting', 'carrot', 'top', 'in', ',', 'well', ',', 'anything', ',', 'but', 'riddle', 'me', 'this', ':', 'who', 'better', 'to', 'direct', 'a', 'film', "that's", 'set', 'in', 'the', 'ghetto', 'and', 'features', 'really', 'violent', 'street', 'crime', 'than', 'the', 'mad', 'geniuses', 'behind', 'menace', 'ii', 'society', '?', 'the', 'ghetto', 'in', 'question', 'is', ',', 'of', 'course', ',', 'whitechapel', 'in', '1888', "london's", 'east', 'end', '.', "it's", 'a', 'filthy', ',', 'sooty', 'place', 'where', 'the', 'whores', '(', 'called', '"', 'unfortunates', '"', ')', 'are', 'starting', 'to', 'get', 'a', 'little', 'nervous', 'about', 'this', 'mysterious', 'psychopath', 'who', 'has', 'been', 'carving', 'through', 'their', 'profession', 'with', 'surgical', 'precision', '.', 'when', 'the', 'first', 'stiff', 'turns', 'up', ',', 'copper', 'peter', 'godley', '(', 'robbie', 'coltrane', ',', 'the', 'world', 'is', 'not', 'enough', ')', 'calls', 'in', 'inspector', 'frederick', 'abberline', '(', 'johnny', 'depp', ',', 'blow', ')', 'to', 'crack', 'the', 'case', '.', 'abberline', ',', 'a', 'widower', ',', 'has', 'prophetic', 'dreams', 'he', 'unsuccessfully', 'tries', 'to', 'quell', 'with', 'copious', 'amounts', 'of', 'absinthe', 'and', 'opium', '.', 'upon', 'arriving', 'in', 'whitechapel', ',', 'he', 'befriends', 'an', 'unfortunate', 'named', 'mary', 'kelly', '(', 'heather', 'graham', ',', 'say', 'it', "isn't", 'so', ')', 'and', 'proceeds', 'to', 'investigate', 'the', 'horribly', 'gruesome', 'crimes', 'that', 'even', 'the', 'police', 'surgeon', "can't", 'stomach', '.', 'i', "don't", 'think', 'anyone', 'needs', 'to', 'be', 'briefed', 'on', 'jack', 'the', 'ripper', ',', 'so', 'i', "won't", 'go', 'into', 'the', 'particulars', 'here', ',', 'other', 'than', 'to', 'say', 'moore', 'and', 'campbell', 'have', 'a', 'unique', 'and', 'interesting', 'theory', 'about', 'both', 'the', 'identity', 'of', 'the', 'killer', 'and', 'the', 'reasons', 'he', 'chooses', 'to', 'slay', '.', 'in', 'the', 'comic', ',', 'they', "don't", 'bother', 'cloaking', 'the', 'identity', 'of', 'the', 'ripper', ',', 'but', 'screenwriters', 'terry', 'hayes', '(', 'vertical', 'limit', ')', 'and', 'rafael', 'yglesias', '(', 'les', 'mis', '?', 'rables', ')', 'do', 'a', 'good', 'job', 'of', 'keeping', 'him', 'hidden', 'from', 'viewers', 'until', 'the', 'very', 'end', '.', "it's", 'funny', 'to', 'watch', 'the', 'locals',  ...
# 802

# %% [markdown]
# ### Change la ponctuation en espace vide

# %%
table = str.maketrans('', '', string.punctuation)
tokens = [w.translate(table) for w in tokens]
tokens
# Out:
# ['films',
#  'adapted',
#  'from',
#  'comic',
#  'books',
#  'have',
#  'had',
#  'plenty',
#  'of',
#  'success',
#  '',
#  'whether',
#  'theyre',
#  'about',
#  'superheroes',
#  '',
#  'batman',
#  '',
#  'superman',
#  '',
#  'spawn',
#  '',
#  '',
#  'or',
#  'geared',
#  'toward',
#  'kids',
#  '',
#  'casper',
#  '',
#  'or',
#  'the',
#  'arthouse',
#  'crowd',
#  '',
#  'ghost',
#  'world',
#  '',
#  '',
#  'but',
#  'theres',
#  'never',
#  'really',
#  'been',
#  'a',
#  'comic',
#  'book',
#  'like',
#  'from',
#  'hell',
#  'before',
#  '',
#  'for',
#  'starters',
#  '',
#  'it',
#  'was',
#  'created',
#  'by',
#  'alan',
#  'moore',
#  '',
#  'and',
#  'eddie',
#  'campbell',
#  '',
#  '',
#  'who',
#  'brought',
#  'the',
#  'medium',
#  'to',
#  'a',
#  'whole',
#  'new',
#  'level',
#  'in',
#  'the',
#  'mid',
#  '80s',
#  'with',
#  'a',
#  '12part',
#  'series',
#  'called',
#  'the',
#  'watchmen',
#  '',
#  'to',
#  'say',
#  'moore',
#  'and',
#  'campbell',
#  'thoroughly',
#  'researched',
#  'the',
#  'subject',
#  'of',
#  'jack',
#  'the',
#  'ripper',
#  'would',
#  'be',
#  'like',
#  'saying',
#  'michael',
#  'jackson',
#  'is',
#  'starting',
#  'to',
#  'look',
#  'a',
#  'little',
#  'odd',
#  '',
#  'the',
#  'book',
#  '',
#  'or',
#  '',
#  'graphic',
#  'novel',
#  '',
#  '',
#  'if',
#  'you',
#  'will',
#  '',
#  'is',
#  'over',
#  '500',
#  'pages',
#  'long',
#  'and',
#  'includes',
#  'nearly',
#  '30',
#  'more',
#  'that',
#  'consist',
#  'of',
#  'nothing',
#  'but',
#  'footnotes',
#  '',
#  'in',
#  'other',
#  'words',
#  '',
#  'dont',
#  'dismiss',
#  'this',
#  'film',
#  'because',
#  'of',
#  'its',
#  'source',
#  '',
#  'if',
#  'you',
#  'can',
#  'get',
#  'past',
#  'the',
#  'whole',
#  'comic',
#  'book',
#  'thing',
#  '',
#  'you',
#  'might',
#  'find',
#  'another',
#  'stumbling',
#  'block',
#  'in',
#  'from',
#  'hells',
#  'directors',
#  '',
#  'albert',
#  'and',
#  'allen',
#  'hughes',
#  '',
#  'getting',
#  'the',
#  'hughes',
#  'brothers',
#  'to',
#  'direct',
#  'this',
#  'seems',
#  'almost',
#  'as',
#  'ludicrous',
#  'as',
#  'casting',
#  'carrot',
#  'top',
#  'in',
#  '',
#  'well',
#  '',
#  'anything',
#  '',
#  'but',
#  'riddle',
#  'me',
#  'this',
#  '',
#  'who',
#  'better',
#  'to',
#  'direct',
#  'a',
#  'film',
#  'thats',
#  'set',
#  'in',
#  'the',
#  'ghetto',
#  'and',
#  'features',
#  'really',
#  'violent',
#  'street',
#  'crime',
#  'than',
#  'the',
#  'mad',
#  'geniuses',
#  'behind',
#  'menace',
#  'ii',
#  'society',
#  '',
#  'the',
#  'ghetto',
#  'in',
#  'question',
#  'is',
#  '',
#  'of',
#  'course',
#  '',
#  'whitechapel',
#  'in',
#  '1888',
#  'londons',
#  'east',
#  'end',
#  '',
#  'its',
#  'a',
#  'filthy',
#  '',
#  'sooty',
#  'place',
#  'where',
#  'the',
#  'whores',
#  '',
#  'called',
#  '',
#  'unfortunates',
#  '',
#  '',
#  'are',
#  'starting',
#  'to',
#  'get',
#  'a',
#  'little',
#  'nervous',
#  'about',
#  'this',
#  'mysterious',
#  'psychopath',
#  'who',
#  'has',
#  'been',
#  'carving',
#  'through',
#  'their',
#  'profession',
#  'with',
#  'surgical',
#  'precision',
#  '',
#  'when',
#  'the',
#  'first',
#  'stiff',
#  'turns',
#  'up',
#  '',
#  'copper',
#  'peter',
#  'godley',
#  '',
#  'robbie',
#  'coltrane',
#  '',
#  'the',
#  'world',
#  'is',
#  'not',
#  'enough',
#  '',
#  'calls',
#  'in',
#  'inspector',
#  'frederick',
#  'abberline',
#  '',
#  'johnny',
#  'depp',
#  '',
#  'blow',
#  '',
#  'to',
#  'crack',
#  'the',
#  'case',
#  '',
#  'abberline',
#  '',
#  'a',
#  'widower',
#  '',
#  'has',
#  'prophetic',
#  'dreams',
#  'he',
#  'unsuccessfully',
#  'tries',
#  'to',
#  'quell',
#  'with',
#  'copious',
#  'amounts',
#  'of',
#  'absinthe',
#  'and',
#  'opium',
#  '',
#  'upon',
#  'arriving',
#  'in',
#  'whitechapel',
#  '',
#  'he',
#  'befriends',
#  'an',
#  'unfortunate',
#  'named',
#  'mary',
#  'kelly',
#  '',
#  'heather',
#  'graham',
#  '',
#  'say',
#  'it',
#  'isnt',
#  'so',
#  '',
#  'and',
#  'proceeds',
#  'to',
#  'investigate',
#  'the',
#  'horribly',
#  'gruesome',
#  'crimes',
#  'that',
#  'even',
#  'the',
#  'police',
#  'surgeon',
#  'cant',
#  'stomach',
#  '',
#  'i',
#  'dont',
#  'think',
#  'anyone',
#  'needs',
#  'to',
#  'be',
#  'briefed',
#  'on',
#  'jack',
#  'the',
#  'ripper',
#  '',
#  'so',
#  'i',
#  'wont',
#  'go',
#  'into',
#  'the',
#  'particulars',
#  'here',
#  '',
#  'other',
#  'than',
#  'to',
#  'say',
#  'moore',
#  'and',
#  'campbell',
#  'have',
#  'a',
#  'unique',
#  'and',
#  'interesting',
#  'theory',
#  'about',
#  'both',
#  'the',
#  'identity',
#  'of',
#  'the',
#  'killer',
#  'and',
#  'the',
#  'reasons',
#  'he',
#  'chooses',
#  'to',
#  'slay',
#  '',
#  'in',
#  'the',
#  'comic',
#  '',
#  'they',
#  'dont',
#  'bother',
#  'cloaking',
#  'the',
#  'identity',
#  'of',
#  'the',
#  'ripper',
#  '',
#  'but',
#  'screenwriters',
#  'terry',
#  'hayes',
#  '',
#  'vertical',
#  'limit',
#  '',
#  'and',
#  'rafael',
#  'yglesias',
#  '',
#  'les',
#  'mis',
#  '',
#  'rables',
#  '',
#  'do',
#  'a',
#  'good',
#  'job',
#  'of',
#  'keeping',
#  'him',
#  'hidden',
#  'from',
#  'viewers',
#  'until',
#  'the',
#  'very',
#  'end',
#  '',
#  'its',
#  'funny',
#  'to',
#  'watch',
#  'the',
#  'locals',
#  'blindly',
#  'point',
#  'the',
#  'finger',
#  'of',
#  'blame',
#  'at',
#  'jews',
#  'and',
#  'indians',
#  'because',
#  '',
#  'after',
#  'all',
#  '',
#  'an',
#  'englishman',
#  'could',
#  'never',
#  'be',
#  'capable',
#  'of',
#  'committing',
#  'such',
#  'ghastly',
#  'acts',
#  '',
#  'and',
#  'from',
#  'hells',
#  'ending',
#  'had',
#  'me',
#  'whistling',
#  'the',
#  'stonecutters',
#  'song',
#  'from',
#  'the',
#  'simpsons',
#  'for',
#  'days',
#  '',
#  '',
#  'who',
#  'holds',
#  'back',
#  'the',
#  'electric',
#  'carwho',
#  'made',
#  'steve',
#  'guttenberg',
#  'a',
#  'star',
#  '',
#  '',
#  '',
#  '',
#  'dont',
#  'worry',
#  '',
#  'itll',
#  'all',
#  'make',
#  'sense',
#  'when',
#  'you',
#  'see',
#  'it',
#  '',
#  'now',
#  'onto',
#  'from',
#  'hells',
#  'appearance',
#  '',
#  'its',
#  'certainly',
#  'dark',
#  'and',
#  'bleak',
#  'enough',
#  '',
#  'and',
#  'its',
#  'surprising',
#  'to',
#  'see',
#  'how',
#  'much',
#  'more',
#  'it',
#  'looks',
#  'like',
#  'a',
#  'tim',
#  'burton',
#  'film',
#  'than',
#  'planet',
#  'of',
#  'the',
#  'apes',
#  'did',
#  '',
#  'at',
#  'times',
#  '',
#  'it',
#  'seems',
#  'like',
#  'sleepy',
#  'hollow',
#  '2',
#  '',
#  '',
#  'the',
#  'print',
#  'i',
#  'saw',
#  'wasnt',
#  'completely',
#  'finished',
#  '',
#  'both',
#  'color',
#  'and',
#  'music',
#  'had',
#  'not',
#  'been',
#  'finalized',
#  '',
#  'so',
#  'no',
#  'comments',
#  'about',
#  'marilyn',
#  'manson',
#  '',
#  '',
#  'but',
#  'cinematographer',
#  'peter',
#  'deming',
#  '',
#  'dont',
#  'say',
#  'a',
#  'word',
#  '',
#  'ably',
#  'captures',
#  'the',
#  'dreariness',
#  'of',
#  'victorianera',
#  'london',
#  'and',
#  'helped',
#  'make',
#  'the',
#  'flashy',
#  'killing',
#  'scenes',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'crazy',
#  'flashbacks',
#  'in',
#  'twin',
#  'peaks',
#  '',
#  'even',
#  'though',
#  'the',
#  'violence',
#  'in',
#  'the',
#  'film',
#  'pales',
#  'in',
#  'comparison',
#  'to',
#  'that',
#  'in',
#  'the',
#  'blackandwhite',
#  'comic',
#  '',
#  'oscar',
#  'winner',
#  'martin',
#  'childs',
#  '',
#  'shakespeare',
#  'in',
#  'love',
#  '',
#  'production',
#  'design',
#  'turns',
#  'the',
#  'original',
#  'prague',
#  'surroundings',
#  'into',
#  'one',
#  'creepy',
#  'place',
#  '',
#  'even',
#  'the',
#  'acting',
#  'in',
#  'from',
#  'hell',
#  'is',
#  'solid',
#  '',
#  'with',
#  'the',
#  'dreamy',
#  'depp',
#  'turning',
#  'in',
#  'a',
#  'typically',
#  'strong',
#  'performance',
#  'and',
#  'deftly',
#  'handling',
#  'a',
#  'british',
#  'accent',
#  '',
#  'ians',
#  'holm',
#  '',
#  'joe',
#  'goulds',
#  'secret',
#  '',
#  'and',
#  'richardson',
#  '',
#  '102',
#  'dalmatians',
#  '',
#  'log',
#  'in',
#  'great',
#  'supporting',
#  'roles',
#  '',
#  'but',
#  'the',
#  'big',
#  'surprise',
#  'here',
#  'is',
#  'graham',
#  '',
#  'i',
#  'cringed',
#  'the',
#  'first',
#  'time',
#  'she',
#  'opened',
#  'her',
#  'mouth',
#  '',
#  'imagining',
#  'her',
#  'attempt',
#  'at',
#  'an',
#  'irish',
#  'accent',
#  '',
#  'but',
#  'it',
#  'actually',
#  'wasnt',
#  'half',
#  'bad',
#  '',
#  'the',
#  'film',
#  '',
#  'however',
#  '',
#  'is',
#  'all',
#  'good',
#  '',
#  '2',
#  '',
#  '00',
#  '',
#  'r',
#  'for',
#  'strong',
#  'violencegore',
#  '',
#  'sexuality',
#  '',
#  'language',
#  'and',
#  'drug',
#  'content']

# %% [markdown]
# ### Enlève les tokens non numérique

# %%
tokens = [word for word in tokens if word.isalpha()]
tokens
# Out:
# ['films',
#  'adapted',
#  'from',
#  'comic',
#  'books',
#  'have',
#  'had',
#  'plenty',
#  'of',
#  'success',
#  'whether',
#  'theyre',
#  'about',
#  'superheroes',
#  'batman',
#  'superman',
#  'spawn',
#  'or',
#  'geared',
#  'toward',
#  'kids',
#  'casper',
#  'or',
#  'the',
#  'arthouse',
#  'crowd',
#  'ghost',
#  'world',
#  'but',
#  'theres',
#  'never',
#  'really',
#  'been',
#  'a',
#  'comic',
#  'book',
#  'like',
#  'from',
#  'hell',
#  'before',
#  'for',
#  'starters',
#  'it',
#  'was',
#  'created',
#  'by',
#  'alan',
#  'moore',
#  'and',
#  'eddie',
#  'campbell',
#  'who',
#  'brought',
#  'the',
#  'medium',
#  'to',
#  'a',
#  'whole',
#  'new',
#  'level',
#  'in',
#  'the',
#  'mid',
#  'with',
#  'a',
#  'series',
#  'called',
#  'the',
#  'watchmen',
#  'to',
#  'say',
#  'moore',
#  'and',
#  'campbell',
#  'thoroughly',
#  'researched',
#  'the',
#  'subject',
#  'of',
#  'jack',
#  'the',
#  'ripper',
#  'would',
#  'be',
#  'like',
#  'saying',
#  'michael',
#  'jackson',
#  'is',
#  'starting',
#  'to',
#  'look',
#  'a',
#  'little',
#  'odd',
#  'the',
#  'book',
#  'or',
#  'graphic',
#  'novel',
#  'if',
#  'you',
#  'will',
#  'is',
#  'over',
#  'pages',
#  'long',
#  'and',
#  'includes',
#  'nearly',
#  'more',
#  'that',
#  'consist',
#  'of',
#  'nothing',
#  'but',
#  'footnotes',
#  'in',
#  'other',
#  'words',
#  'dont',
#  'dismiss',
#  'this',
#  'film',
#  'because',
#  'of',
#  'its',
#  'source',
#  'if',
#  'you',
#  'can',
#  'get',
#  'past',
#  'the',
#  'whole',
#  'comic',
#  'book',
#  'thing',
#  'you',
#  'might',
#  'find',
#  'another',
#  'stumbling',
#  'block',
#  'in',
#  'from',
#  'hells',
#  'directors',
#  'albert',
#  'and',
#  'allen',
#  'hughes',
#  'getting',
#  'the',
#  'hughes',
#  'brothers',
#  'to',
#  'direct',
#  'this',
#  'seems',
#  'almost',
#  'as',
#  'ludicrous',
#  'as',
#  'casting',
#  'carrot',
#  'top',
#  'in',
#  'well',
#  'anything',
#  'but',
#  'riddle',
#  'me',
#  'this',
#  'who',
#  'better',
#  'to',
#  'direct',
#  'a',
#  'film',
#  'thats',
#  'set',
#  'in',
#  'the',
#  'ghetto',
#  'and',
#  'features',
#  'really',
#  'violent',
#  'street',
#  'crime',
#  'than',
#  'the',
#  'mad',
#  'geniuses',
#  'behind',
#  'menace',
#  'ii',
#  'society',
#  'the',
#  'ghetto',
#  'in',
#  'question',
#  'is',
#  'of',
#  'course',
#  'whitechapel',
#  'in',
#  'londons',
#  'east',
#  'end',
#  'its',
#  'a',
#  'filthy',
#  'sooty',
#  'place',
#  'where',
#  'the',
#  'whores',
#  'called',
#  'unfortunates',
#  'are',
#  'starting',
#  'to',
#  'get',
#  'a',
#  'little',
#  'nervous',
#  'about',
#  'this',
#  'mysterious',
#  'psychopath',
#  'who',
#  'has',
#  'been',
#  'carving',
#  'through',
#  'their',
#  'profession',
#  'with',
#  'surgical',
#  'precision',
#  'when',
#  'the',
#  'first',
#  'stiff',
#  'turns',
#  'up',
#  'copper',
#  'peter',
#  'godley',
#  'robbie',
#  'coltrane',
#  'the',
#  'world',
#  'is',
#  'not',
#  'enough',
#  'calls',
#  'in',
#  'inspector',
#  'frederick',
#  'abberline',
#  'johnny',
#  'depp',
#  'blow',
#  'to',
#  'crack',
#  'the',
#  'case',
#  'abberline',
#  'a',
#  'widower',
#  'has',
#  'prophetic',
#  'dreams',
#  'he',
#  'unsuccessfully',
#  'tries',
#  'to',
#  'quell',
#  'with',
#  'copious',
#  'amounts',
#  'of',
#  'absinthe',
#  'and',
#  'opium',
#  'upon',
#  'arriving',
#  'in',
#  'whitechapel',
#  'he',
#  'befriends',
#  'an',
#  'unfortunate',
#  'named',
#  'mary',
#  'kelly',
#  'heather',
#  'graham',
#  'say',
#  'it',
#  'isnt',
#  'so',
#  'and',
#  'proceeds',
#  'to',
#  'investigate',
#  'the',
#  'horribly',
#  'gruesome',
#  'crimes',
#  'that',
#  'even',
#  'the',
#  'police',
#  'surgeon',
#  'cant',
#  'stomach',
#  'i',
#  'dont',
#  'think',
#  'anyone',
#  'needs',
#  'to',
#  'be',
#  'briefed',
#  'on',
#  'jack',
#  'the',
#  'ripper',
#  'so',
#  'i',
#  'wont',
#  'go',
#  'into',
#  'the',
#  'particulars',
#  'here',
#  'other',
#  'than',
#  'to',
#  'say',
#  'moore',
#  'and',
#  'campbell',
#  'have',
#  'a',
#  'unique',
#  'and',
#  'interesting',
#  'theory',
#  'about',
#  'both',
#  'the',
#  'identity',
#  'of',
#  'the',
#  'killer',
#  'and',
#  'the',
#  'reasons',
#  'he',
#  'chooses',
#  'to',
#  'slay',
#  'in',
#  'the',
#  'comic',
#  'they',
#  'dont',
#  'bother',
#  'cloaking',
#  'the',
#  'identity',
#  'of',
#  'the',
#  'ripper',
#  'but',
#  'screenwriters',
#  'terry',
#  'hayes',
#  'vertical',
#  'limit',
#  'and',
#  'rafael',
#  'yglesias',
#  'les',
#  'mis',
#  'rables',
#  'do',
#  'a',
#  'good',
#  'job',
#  'of',
#  'keeping',
#  'him',
#  'hidden',
#  'from',
#  'viewers',
#  'until',
#  'the',
#  'very',
#  'end',
#  'its',
#  'funny',
#  'to',
#  'watch',
#  'the',
#  'locals',
#  'blindly',
#  'point',
#  'the',
#  'finger',
#  'of',
#  'blame',
#  'at',
#  'jews',
#  'and',
#  'indians',
#  'because',
#  'after',
#  'all',
#  'an',
#  'englishman',
#  'could',
#  'never',
#  'be',
#  'capable',
#  'of',
#  'committing',
#  'such',
#  'ghastly',
#  'acts',
#  'and',
#  'from',
#  'hells',
#  'ending',
#  'had',
#  'me',
#  'whistling',
#  'the',
#  'stonecutters',
#  'song',
#  'from',
#  'the',
#  'simpsons',
#  'for',
#  'days',
#  'who',
#  'holds',
#  'back',
#  'the',
#  'electric',
#  'carwho',
#  'made',
#  'steve',
#  'guttenberg',
#  'a',
#  'star',
#  'dont',
#  'worry',
#  'itll',
#  'all',
#  'make',
#  'sense',
#  'when',
#  'you',
#  'see',
#  'it',
#  'now',
#  'onto',
#  'from',
#  'hells',
#  'appearance',
#  'its',
#  'certainly',
#  'dark',
#  'and',
#  'bleak',
#  'enough',
#  'and',
#  'its',
#  'surprising',
#  'to',
#  'see',
#  'how',
#  'much',
#  'more',
#  'it',
#  'looks',
#  'like',
#  'a',
#  'tim',
#  'burton',
#  'film',
#  'than',
#  'planet',
#  'of',
#  'the',
#  'apes',
#  'did',
#  'at',
#  'times',
#  'it',
#  'seems',
#  'like',
#  'sleepy',
#  'hollow',
#  'the',
#  'print',
#  'i',
#  'saw',
#  'wasnt',
#  'completely',
#  'finished',
#  'both',
#  'color',
#  'and',
#  'music',
#  'had',
#  'not',
#  'been',
#  'finalized',
#  'so',
#  'no',
#  'comments',
#  'about',
#  'marilyn',
#  'manson',
#  'but',
#  'cinematographer',
#  'peter',
#  'deming',
#  'dont',
#  'say',
#  'a',
#  'word',
#  'ably',
#  'captures',
#  'the',
#  'dreariness',
#  'of',
#  'victorianera',
#  'london',
#  'and',
#  'helped',
#  'make',
#  'the',
#  'flashy',
#  'killing',
#  'scenes',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'crazy',
#  'flashbacks',
#  'in',
#  'twin',
#  'peaks',
#  'even',
#  'though',
#  'the',
#  'violence',
#  'in',
#  'the',
#  'film',
#  'pales',
#  'in',
#  'comparison',
#  'to',
#  'that',
#  'in',
#  'the',
#  'blackandwhite',
#  'comic',
#  'oscar',
#  'winner',
#  'martin',
#  'childs',
#  'shakespeare',
#  'in',
#  'love',
#  'production',
#  'design',
#  'turns',
#  'the',
#  'original',
#  'prague',
#  'surroundings',
#  'into',
#  'one',
#  'creepy',
#  'place',
#  'even',
#  'the',
#  'acting',
#  'in',
#  'from',
#  'hell',
#  'is',
#  'solid',
#  'with',
#  'the',
#  'dreamy',
#  'depp',
#  'turning',
#  'in',
#  'a',
#  'typically',
#  'strong',
#  'performance',
#  'and',
#  'deftly',
#  'handling',
#  'a',
#  'british',
#  'accent',
#  'ians',
#  'holm',
#  'joe',
#  'goulds',
#  'secret',
#  'and',
#  'richardson',
#  'dalmatians',
#  'log',
#  'in',
#  'great',
#  'supporting',
#  'roles',
#  'but',
#  'the',
#  'big',
#  'surprise',
#  'here',
#  'is',
#  'graham',
#  'i',
#  'cringed',
#  'the',
#  'first',
#  'time',
#  'she',
#  'opened',
#  'her',
#  'mouth',
#  'imagining',
#  'her',
#  'attempt',
#  'at',
#  'an',
#  'irish',
#  'accent',
#  'but',
#  'it',
#  'actually',
#  'wasnt',
#  'half',
#  'bad',
#  'the',
#  'film',
#  'however',
#  'is',
#  'all',
#  'good',
#  'r',
#  'for',
#  'strong',
#  'violencegore',
#  'sexuality',
#  'language',
#  'and',
#  'drug',
#  'content']

# %% [markdown]
# ### Enlève les stop words (mots vides)

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
tokens = [w for w in tokens if not w in stop_words]
tokens
# Out:
# ['films',
#  'adapted',
#  'comic',
#  'books',
#  'plenty',
#  'success',
#  'whether',
#  'theyre',
#  'superheroes',
#  'batman',
#  'superman',
#  'spawn',
#  'geared',
#  'toward',
#  'kids',
#  'casper',
#  'arthouse',
#  'crowd',
#  'ghost',
#  'world',
#  'theres',
#  'never',
#  'really',
#  'comic',
#  'book',
#  'like',
#  'hell',
#  'starters',
#  'created',
#  'alan',
#  'moore',
#  'eddie',
#  'campbell',
#  'brought',
#  'medium',
#  'whole',
#  'new',
#  'level',
#  'mid',
#  'series',
#  'called',
#  'watchmen',
#  'say',
#  'moore',
#  'campbell',
#  'thoroughly',
#  'researched',
#  'subject',
#  'jack',
#  'ripper',
#  'would',
#  'like',
#  'saying',
#  'michael',
#  'jackson',
#  'starting',
#  'look',
#  'little',
#  'odd',
#  'book',
#  'graphic',
#  'novel',
#  'pages',
#  'long',
#  'includes',
#  'nearly',
#  'consist',
#  'nothing',
#  'footnotes',
#  'words',
#  'dont',
#  'dismiss',
#  'film',
#  'source',
#  'get',
#  'past',
#  'whole',
#  'comic',
#  'book',
#  'thing',
#  'might',
#  'find',
#  'another',
#  'stumbling',
#  'block',
#  'hells',
#  'directors',
#  'albert',
#  'allen',
#  'hughes',
#  'getting',
#  'hughes',
#  'brothers',
#  'direct',
#  'seems',
#  'almost',
#  'ludicrous',
#  'casting',
#  'carrot',
#  'top',
#  'well',
#  'anything',
#  'riddle',
#  'better',
#  'direct',
#  'film',
#  'thats',
#  'set',
#  'ghetto',
#  'features',
#  'really',
#  'violent',
#  'street',
#  'crime',
#  'mad',
#  'geniuses',
#  'behind',
#  'menace',
#  'ii',
#  'society',
#  'ghetto',
#  'question',
#  'course',
#  'whitechapel',
#  'londons',
#  'east',
#  'end',
#  'filthy',
#  'sooty',
#  'place',
#  'whores',
#  'called',
#  'unfortunates',
#  'starting',
#  'get',
#  'little',
#  'nervous',
#  'mysterious',
#  'psychopath',
#  'carving',
#  'profession',
#  'surgical',
#  'precision',
#  'first',
#  'stiff',
#  'turns',
#  'copper',
#  'peter',
#  'godley',
#  'robbie',
#  'coltrane',
#  'world',
#  'enough',
#  'calls',
#  'inspector',
#  'frederick',
#  'abberline',
#  'johnny',
#  'depp',
#  'blow',
#  'crack',
#  'case',
#  'abberline',
#  'widower',
#  'prophetic',
#  'dreams',
#  'unsuccessfully',
#  'tries',
#  'quell',
#  'copious',
#  'amounts',
#  'absinthe',
#  'opium',
#  'upon',
#  'arriving',
#  'whitechapel',
#  'befriends',
#  'unfortunate',
#  'named',
#  'mary',
#  'kelly',
#  'heather',
#  'graham',
#  'say',
#  'isnt',
#  'proceeds',
#  'investigate',
#  'horribly',
#  'gruesome',
#  'crimes',
#  'even',
#  'police',
#  'surgeon',
#  'cant',
#  'stomach',
#  'dont',
#  'think',
#  'anyone',
#  'needs',
#  'briefed',
#  'jack',
#  'ripper',
#  'wont',
#  'go',
#  'particulars',
#  'say',
#  'moore',
#  'campbell',
#  'unique',
#  'interesting',
#  'theory',
#  'identity',
#  'killer',
#  'reasons',
#  'chooses',
#  'slay',
#  'comic',
#  'dont',
#  'bother',
#  'cloaking',
#  'identity',
#  'ripper',
#  'screenwriters',
#  'terry',
#  'hayes',
#  'vertical',
#  'limit',
#  'rafael',
#  'yglesias',
#  'les',
#  'mis',
#  'rables',
#  'good',
#  'job',
#  'keeping',
#  'hidden',
#  'viewers',
#  'end',
#  'funny',
#  'watch',
#  'locals',
#  'blindly',
#  'point',
#  'finger',
#  'blame',
#  'jews',
#  'indians',
#  'englishman',
#  'could',
#  'never',
#  'capable',
#  'committing',
#  'ghastly',
#  'acts',
#  'hells',
#  'ending',
#  'whistling',
#  'stonecutters',
#  'song',
#  'simpsons',
#  'days',
#  'holds',
#  'back',
#  'electric',
#  'carwho',
#  'made',
#  'steve',
#  'guttenberg',
#  'star',
#  'dont',
#  'worry',
#  'itll',
#  'make',
#  'sense',
#  'see',
#  'onto',
#  'hells',
#  'appearance',
#  'certainly',
#  'dark',
#  'bleak',
#  'enough',
#  'surprising',
#  'see',
#  'much',
#  'looks',
#  'like',
#  'tim',
#  'burton',
#  'film',
#  'planet',
#  'apes',
#  'times',
#  'seems',
#  'like',
#  'sleepy',
#  'hollow',
#  'print',
#  'saw',
#  'wasnt',
#  'completely',
#  'finished',
#  'color',
#  'music',
#  'finalized',
#  'comments',
#  'marilyn',
#  'manson',
#  'cinematographer',
#  'peter',
#  'deming',
#  'dont',
#  'say',
#  'word',
#  'ably',
#  'captures',
#  'dreariness',
#  'victorianera',
#  'london',
#  'helped',
#  'make',
#  'flashy',
#  'killing',
#  'scenes',
#  'remind',
#  'crazy',
#  'flashbacks',
#  'twin',
#  'peaks',
#  'even',
#  'though',
#  'violence',
#  'film',
#  'pales',
#  'comparison',
#  'blackandwhite',
#  'comic',
#  'oscar',
#  'winner',
#  'martin',
#  'childs',
#  'shakespeare',
#  'love',
#  'production',
#  'design',
#  'turns',
#  'original',
#  'prague',
#  'surroundings',
#  'one',
#  'creepy',
#  'place',
#  'even',
#  'acting',
#  'hell',
#  'solid',
#  'dreamy',
#  'depp',
#  'turning',
#  'typically',
#  'strong',
#  'performance',
#  'deftly',
#  'handling',
#  'british',
#  'accent',
#  'ians',
#  'holm',
#  'joe',
#  'goulds',
#  'secret',
#  'richardson',
#  'dalmatians',
#  'log',
#  'great',
#  'supporting',
#  'roles',
#  'big',
#  'surprise',
#  'graham',
#  'cringed',
#  'first',
#  'time',
#  'opened',
#  'mouth',
#  'imagining',
#  'attempt',
#  'irish',
#  'accent',
#  'actually',
#  'wasnt',
#  'half',
#  'bad',
#  'film',
#  'however',
#  'good',
#  'r',
#  'strong',
#  'violencegore',
#  'sexuality',
#  'language',
#  'drug',
#  'content']

# %% [markdown]
# ### Enlève les mots de moins d'une lettre

# %%
tokens = [word for word in tokens if len(word) > 1]
tokens
# Out:
# ['films',
#  'adapted',
#  'comic',
#  'books',
#  'plenty',
#  'success',
#  'whether',
#  'theyre',
#  'superheroes',
#  'batman',
#  'superman',
#  'spawn',
#  'geared',
#  'toward',
#  'kids',
#  'casper',
#  'arthouse',
#  'crowd',
#  'ghost',
#  'world',
#  'theres',
#  'never',
#  'really',
#  'comic',
#  'book',
#  'like',
#  'hell',
#  'starters',
#  'created',
#  'alan',
#  'moore',
#  'eddie',
#  'campbell',
#  'brought',
#  'medium',
#  'whole',
#  'new',
#  'level',
#  'mid',
#  'series',
#  'called',
#  'watchmen',
#  'say',
#  'moore',
#  'campbell',
#  'thoroughly',
#  'researched',
#  'subject',
#  'jack',
#  'ripper',
#  'would',
#  'like',
#  'saying',
#  'michael',
#  'jackson',
#  'starting',
#  'look',
#  'little',
#  'odd',
#  'book',
#  'graphic',
#  'novel',
#  'pages',
#  'long',
#  'includes',
#  'nearly',
#  'consist',
#  'nothing',
#  'footnotes',
#  'words',
#  'dont',
#  'dismiss',
#  'film',
#  'source',
#  'get',
#  'past',
#  'whole',
#  'comic',
#  'book',
#  'thing',
#  'might',
#  'find',
#  'another',
#  'stumbling',
#  'block',
#  'hells',
#  'directors',
#  'albert',
#  'allen',
#  'hughes',
#  'getting',
#  'hughes',
#  'brothers',
#  'direct',
#  'seems',
#  'almost',
#  'ludicrous',
#  'casting',
#  'carrot',
#  'top',
#  'well',
#  'anything',
#  'riddle',
#  'better',
#  'direct',
#  'film',
#  'thats',
#  'set',
#  'ghetto',
#  'features',
#  'really',
#  'violent',
#  'street',
#  'crime',
#  'mad',
#  'geniuses',
#  'behind',
#  'menace',
#  'ii',
#  'society',
#  'ghetto',
#  'question',
#  'course',
#  'whitechapel',
#  'londons',
#  'east',
#  'end',
#  'filthy',
#  'sooty',
#  'place',
#  'whores',
#  'called',
#  'unfortunates',
#  'starting',
#  'get',
#  'little',
#  'nervous',
#  'mysterious',
#  'psychopath',
#  'carving',
#  'profession',
#  'surgical',
#  'precision',
#  'first',
#  'stiff',
#  'turns',
#  'copper',
#  'peter',
#  'godley',
#  'robbie',
#  'coltrane',
#  'world',
#  'enough',
#  'calls',
#  'inspector',
#  'frederick',
#  'abberline',
#  'johnny',
#  'depp',
#  'blow',
#  'crack',
#  'case',
#  'abberline',
#  'widower',
#  'prophetic',
#  'dreams',
#  'unsuccessfully',
#  'tries',
#  'quell',
#  'copious',
#  'amounts',
#  'absinthe',
#  'opium',
#  'upon',
#  'arriving',
#  'whitechapel',
#  'befriends',
#  'unfortunate',
#  'named',
#  'mary',
#  'kelly',
#  'heather',
#  'graham',
#  'say',
#  'isnt',
#  'proceeds',
#  'investigate',
#  'horribly',
#  'gruesome',
#  'crimes',
#  'even',
#  'police',
#  'surgeon',
#  'cant',
#  'stomach',
#  'dont',
#  'think',
#  'anyone',
#  'needs',
#  'briefed',
#  'jack',
#  'ripper',
#  'wont',
#  'go',
#  'particulars',
#  'say',
#  'moore',
#  'campbell',
#  'unique',
#  'interesting',
#  'theory',
#  'identity',
#  'killer',
#  'reasons',
#  'chooses',
#  'slay',
#  'comic',
#  'dont',
#  'bother',
#  'cloaking',
#  'identity',
#  'ripper',
#  'screenwriters',
#  'terry',
#  'hayes',
#  'vertical',
#  'limit',
#  'rafael',
#  'yglesias',
#  'les',
#  'mis',
#  'rables',
#  'good',
#  'job',
#  'keeping',
#  'hidden',
#  'viewers',
#  'end',
#  'funny',
#  'watch',
#  'locals',
#  'blindly',
#  'point',
#  'finger',
#  'blame',
#  'jews',
#  'indians',
#  'englishman',
#  'could',
#  'never',
#  'capable',
#  'committing',
#  'ghastly',
#  'acts',
#  'hells',
#  'ending',
#  'whistling',
#  'stonecutters',
#  'song',
#  'simpsons',
#  'days',
#  'holds',
#  'back',
#  'electric',
#  'carwho',
#  'made',
#  'steve',
#  'guttenberg',
#  'star',
#  'dont',
#  'worry',
#  'itll',
#  'make',
#  'sense',
#  'see',
#  'onto',
#  'hells',
#  'appearance',
#  'certainly',
#  'dark',
#  'bleak',
#  'enough',
#  'surprising',
#  'see',
#  'much',
#  'looks',
#  'like',
#  'tim',
#  'burton',
#  'film',
#  'planet',
#  'apes',
#  'times',
#  'seems',
#  'like',
#  'sleepy',
#  'hollow',
#  'print',
#  'saw',
#  'wasnt',
#  'completely',
#  'finished',
#  'color',
#  'music',
#  'finalized',
#  'comments',
#  'marilyn',
#  'manson',
#  'cinematographer',
#  'peter',
#  'deming',
#  'dont',
#  'say',
#  'word',
#  'ably',
#  'captures',
#  'dreariness',
#  'victorianera',
#  'london',
#  'helped',
#  'make',
#  'flashy',
#  'killing',
#  'scenes',
#  'remind',
#  'crazy',
#  'flashbacks',
#  'twin',
#  'peaks',
#  'even',
#  'though',
#  'violence',
#  'film',
#  'pales',
#  'comparison',
#  'blackandwhite',
#  'comic',
#  'oscar',
#  'winner',
#  'martin',
#  'childs',
#  'shakespeare',
#  'love',
#  'production',
#  'design',
#  'turns',
#  'original',
#  'prague',
#  'surroundings',
#  'one',
#  'creepy',
#  'place',
#  'even',
#  'acting',
#  'hell',
#  'solid',
#  'dreamy',
#  'depp',
#  'turning',
#  'typically',
#  'strong',
#  'performance',
#  'deftly',
#  'handling',
#  'british',
#  'accent',
#  'ians',
#  'holm',
#  'joe',
#  'goulds',
#  'secret',
#  'richardson',
#  'dalmatians',
#  'log',
#  'great',
#  'supporting',
#  'roles',
#  'big',
#  'surprise',
#  'graham',
#  'cringed',
#  'first',
#  'time',
#  'opened',
#  'mouth',
#  'imagining',
#  'attempt',
#  'irish',
#  'accent',
#  'actually',
#  'wasnt',
#  'half',
#  'bad',
#  'film',
#  'however',
#  'good',
#  'strong',
#  'violencegore',
#  'sexuality',
#  'language',
#  'drug',
#  'content']

# %% [markdown]
# ### Fonction pour faire tout ça

# %%
from nltk.corpus import stopwords
import string

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# turn a doc into clean tokens
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# load the document
filename = '/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos/cv000_29590.txt'
text = load_doc(filename)
tokens = clean_doc(text)

# %% [markdown]
# ## Créer un vocabulaire
# ==> Contient le compte de tous les mots de toutes les datas

# %%
# define vocab
vocab = Counter()
vocab
# Out:
# Counter()

# %%
def add_doc_to_vocab(filename, vocab):
    # load doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # update counts
    vocab.update(tokens)

# load all docs in a directory
def process_docs(directory, vocab):
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # add doc to vocab
        add_doc_to_vocab(path, vocab)

# %%
# add all docs to vocab
process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab)
process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab)
# print the size of the vocab
print(len(vocab))
# print the top words in the vocab
print(vocab.most_common(50))
# Out:
# 44276
# [('film', 7988), ('one', 4947), ('movie', 4826), ('like', 3205), ('even', 2265), ('good', 2082), ('time', 2042), ('story', 1907), ('films', 1874), ('would', 1845), ('much', 1825), ('also', 1757), ('characters', 1735), ('get', 1726), ('character', 1703), ('two', 1643), ('first', 1590), ('see', 1559), ('way', 1515), ('well', 1512), ('make', 1420), ('really', 1409), ('little', 1353), ('life', 1334), ('plot', 1288), ('people', 1269), ('could', 1249), ('bad', 1249), ('scene', 1241), ('movies', 1238), ('never', 1203), ('best', 1179), ('new', 1141), ('scenes', 1136), ('man', 1131), ('many', 1130), ('doesnt', 1118), ('know', 1092), ('dont', 1091), ('hes', 1024), ('great', 1015), ('another', 993), ('action', 985), ('love', 978), ('us', 967), ('go', 953), ('end', 948), ('director', 948), ('something', 945), ('still', 936)]

# %% [markdown]
# ### Prendre seulement ceux qui ont plus de 2 occurences

# %%
# keep tokens with a min occurrence
min_occurane = 2
tokens = [k for k,c in vocab.items() if c >= min_occurane]
print(len(tokens))
# Out:
# 25782

# %% [markdown]
# ### Enregistrer le vocabulaire

# %%
# save list to file
def save_list(lines, filename):
    # convert lines to a single blob of text
    data = '\n'.join(lines)
    # open file
    file = open(filename, 'w')
    # write text
    file.write(data)
    # close file
    file.close()

# save tokens to a vocabulary file
save_list(tokens, 'vocab.txt')

# %% [markdown]
# ## Convertir to bag of words

# %%
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
    # load the doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [w for w in tokens if w in vocab]
    return ' '.join(tokens)


# load all docs in a directory
def process_docs(directory, vocab):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# %%
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
vocab
# Out:
# {'plotholes',
#  'penetrate',
#  'continual',
#  'forbids',
#  'critique',
#  'demographic',
#  'disappeared',
#  'atrocities',
#  'drowned',
#  'hurlyburly',
#  'arcs',
#  'smuggler',
#  'jarring',
#  'sum',
#  'fitzgerald',
#  'broadcasting',
#  'thwart',
#  'ellroy',
#  'goround',
#  'charmed',
#  'busybody',
#  'impresses',
#  'smalley',
#  'curmudgeon',
#  'getup',
#  'ufos',
#  'dating',
#  'attack',
#  'neither',
#  'nsa',
#  'durning',
#  'aimee',
#  'consoling',
#  'dust',
#  'garnering',
#  'msnbc',
#  'playing',
#  'translation',
#  'villages',
#  'thirteenth',
#  'frizzy',
#  'mediums',
#  'shaffer',
#  'earnest',
#  'purely',
#  'transplant',
#  'viewed',
#  'characterthe',
#  'longlived',
#  'minnie',
#  'factors',
#  'ranges',
#  'abode',
#  'cheapskate',
#  'archers',
#  'agency',
#  'khan',
#  'must',
#  'dreck',
#  'subplot',
#  'outgrown',
#  'ritz',
#  'lapaglias',
#  'wonderfully',
#  'assiduously',
#  'caterpillar',
#  'originator',
#  'dramatics',
#  'oblique',
#  'elimination',
#  'desperate',
#  'todde',
#  'deference',
#  'smacks',
#  'magical',
#  'homework',
#  'watchable',
#  'poachers',
#  'leslie',
#  'wizened',
#  'englishman',
#  'wouldve',
#  'bb',
#  'stale',
#  'voyeurs',
#  'dissolve',
#  'wonder',
#  'shred',
#  'creeping',
#  'exhale',
#  'bah',
#  'creativity',
#  'resembling',
#  'rediscover',
#  'jefferson',
#  'vary',
#  'orion',
#  'unplugging',
#  'clears',
#  'keiying',
#  'hubley',
#  'trades',
#  'sleeps',
#  'cradle',
#  'answering',
#  'jury',
#  'samoan',
#  'talal',
#  'dies',
#  'argues',
#  'cigarette',
#  'swims',
#  'elude',
#  'teresa',
#  'mother',
#  'grandpa',
#  'log',
#  'degenerates',
#  'matured',
#  'acquit',
#  'searched',
#  'blunder',
#  'forge',
#  'occurring',
#  'blurred',
#  'avail',
#  'insideout',
#  'strutting',
#  'loneliness',
#  'landings',
#  'fuddyduddy',
#  'variety',
#  'assigns',
#  'preferring',
#  'kurt',
#  'unbroken',
#  'guterman',
#  'introductions',
#  'multicolored',
#  'inspirational',
#  'subjects',
#  'masks',
#  'asshole',
#  'pairing',
#  'artifacts',
#  'backward',
#  'digressions',
#  'unkind',
#  'inhabits',
#  'loveable',
#  'perceive',
#  'tapert',
#  'tahoe',
#  'pullmans',
#  'secondtier',
#  'giants',
#  'hindu',
#  'frighteningly',
#  'erin',
#  'increasing',
#  'irritatingly',
#  'haggard',
#  'farfetched',
#  'bleeds',
#  'currency',
#  'brosnon',
#  'coolio',
#  'umpteen',
#  'natives',
#  'reef',
#  'oavs',
#  'junk',
#  'jojo',
#  'alexanders',
#  'tentative',
#  'literally',
#  'kinski',
#  'miseries',
#  'withdrawal',
#  'traditional',
#  'dwells',
#  'beg',
#  'widows',
#  'condemning',
#  'shun',
#  'judes',
#  'consequences',
#  'rural',
#  'headaches',
#  'coffin',
#  'slacker',
#  'drifting',
#  'succumb',
#  'finger',
#  'ohsocleverly',
#  'brained',
#  'prostitute',
#  'indien',
#  'peet',
#  'citing',
#  'mufti',
#  'cars',
#  'wachowski',
#  'thankless',
#  'beneath',
#  'morsel',
#  'lovin',
#  'grin',
#  'urinating',
#  'net',
#  'tipping',
#  'colourful',
#  'santiago',
#  'verbally',
#  'yearning',
#  'personified',
#  'emotionally',
#  'newborn',
#  'punisher',
#  'rethinking',
#  'awoke',
#  'masterwork',
#  'formulaic',
#  'basing',
#  'indecisive',
#  'dramatic',
#  'jake',
#  'friction',
#  'tidal',
#  'nina',
#  'rollerblades',
#  'phyllis',
#  'goldsman',
#  'connecting',
#  'sewage',
#  'daytoday',
#  'envisions',
#  'barbarians',
#  'unpleasantness',
#  'distraction',
#  'misty',
#  'brewster',
#  'secure',
#  'seclusion',
#  'morneau',
#  'tux',
#  'whitfield',
#  'comes',
#  'rapes',
#  'depended',
#  'thinnest',
#  'lifelong',
#  'fluffy',
#  'grady',
#  'psychosexual',
#  'banshee',
#  'fledgling',
#  'blandest',
#  'functionary',
#  'limb',
#  'fehr',
#  'explains',
#  'anney',
#  'defying',
#  'bothering',
#  'diggler',
#  'couch',
#  'follow',
#  'hurry',
#  'hmmmm',
#  'leoni',
#  'melodrama',
#  'regarded',
#  'halfinteresting',
#  'cowrote',
#  'upon',
#  'arabia',
#  'discredit',
#  'longwinded',
#  'trevor',
#  'pumping',
#  'britain',
#  'supersedes',
#  'shuts',
#  'recites',
#  'lax',
#  'arranges',
#  'selfindulgent',
#  'braugher',
#  'whacking',
#  'adapt',
#  'freshman',
#  'annas',
#  'meal',
#  'enthusiast',
#  'swoop',
#  'yawner',
#  'handsdown',
#  'weakly',
#  'splatter',
#  'overnight',
#  'selfimposed',
#  'boyles',
#  'assemble',
#  'stavros',
#  'actioners',
#  'unpromising',
#  'linc',
#  'scorn',
#  'owens',
#  'drugaddict',
#  'bean',
#  'possessing',
#  'vat',
#  'jimi',
#  'undoubtedly',
#  'batfans',
#  'earthquakes',
#  'pa',
#  'comic',
#  'grangers',
#  'commercially',
#  'kates',
#  'stoops',
#  'programmer',
#  'noise',
#  'fortune',
#  'unshaven',
#  'engagements',
#  'voluntary',
#  'pessimistic',
#  'simplest',
#  'prison',
#  'impeccably',
#  'faltering',
#  'ranging',
#  'kidman',
#  'humans',
#  'reference',
#  'coexist',
#  'junky',
#  'pumpedup',
#  'teachers',
#  'suffer',
#  'fantasizing',
#  'tutelage',
#  'survivor',
#  'tabasco',
#  'harshest',
#  'amazes',
#  'cloke',
#  'flemish',
#  'matinee',
#  'pileup',
#  'discomfort',
#  'lifesaving',
#  'individually',
#  'australian',
#  'garfield',
#  'shaft',
#  'requisite',
#  'baddies',
#  'worn',
#  'mania',
#  'ravaging',
#  'dispondent',
#  'presenting',
#  'sikh',
#  'buxom',
#  'drunkenly',
#  'lesseps',
#  'laws',
#  'accepting',
#  'misfires',
#  'committed',
#  'voyager',
#  'storyboards',
#  'flaunt',
#  'atmospherically',
#  'sadness',
#  'bikini',
#  'portrait',
#  'historic',
#  'seamy',
#  'foreigners',
#  'powders',
#  'margin',
#  'unremarkable',
#  'antisemitism',
#  'arrogant',
#  'dependent',
#  'farmers',
#  'seventh',
#  'chisholm',
#  'crosby',
#  'mired',
#  'defend',
#  'smooths',
#  'clubber',
#  'goliath',
#  'mourning',
#  'replaced',
#  'threatened',
#  'drawback',
#  'theatrics',
#  'graynamores',
#  'lessthanstellar',
#  'nonsense',
#  'distinguishes',
#  'signal',
#  'raoul',
#  'mixes',
#  'brazil',
#  'processes',
#  'kicking',
#  'excite',
#  'nonexistant',
#  'blackmailing',
#  'protection',
#  'ax',
#  'stashed',
#  'nosedives',
#  'breakfast',
#  'eschewed',
#  'skulking',
#  'pizza',
#  'confession',
#  'actively',
#  'joness',
#  'humane',
#  'forefront',
#  'zaniness',
#  'congress',
#  'scriptwriter',
#  'condemns',
#  'cabbies',
#  'read',
#  'squandering',
#  'thirty',
#  'dads',
#  'daphne',
#  'meaney',
#  'dawkins',
#  'mare',
#  'wishes',
#  'furlong',
#  'emmerichs',
#  'cared',
#  'noodles',
#  'mainly',
#  'meeks',
#  'hunch',
#  'senile',
#  'godley',
#  'cheapest',
#  'neice',
#  'argentina',
#  'meatloaf',
#  'sorna',
#  'supremacist',
#  'inconsistencies',
#  'casino',
#  'iknow',
#  'hybrid',
#  'capra',
#  'jerusalem',
#  'sacha',
#  'adventures',
#  'abusers',
#  'ingenue',
#  'bookers',
#  'ferguson',
#  'terraforming',
#  'arlene',
#  'akin',
#  'stunted',
#  'memoirs',
#  'necessarily',
#  'devolves',
#  'luc',
#  'strokes',
#  'change',
#  'pointed',
#  'wrapper',
#  'decoding',
#  'sympathetic',
#  'glaringly',
#  'casts',
#  'copied',
#  'swoon',
#  'mindy',
#  'bursting',
#  'preppie',
#  'joff',
#  'rifle',
#  'webbers',
#  'hub',
#  'treehorn',
#  'mickey',
#  'alices',
#  'concoction',
#  'quieter',
#  'sly',
#  'days',
#  'glob',
#  'mikes',
#  'vignettes',
#  'evils',
#  'griffin',
#  'bondage',
#  'patinkin',
#  'dorky',
#  'rawness',
#  'tiering',
#  'peels',
#  'facetoface',
#  'shower',
#  'devastated',
#  'supervisor',
#  'copyright',
#  'gasoline',
#  'trilogy',
#  'resurrecting',
#  'bind',
#  'ginty',
#  'attentions',
#  'louisas',
#  'prompted',
#  'circulated',
#  'staff',
#  'continuing',
#  'skye',
#  'fishing',
#  'repeatedly',
#  'lunacy',
#  'declines',
#  'description',
#  'earthly',
#  'flirtatious',
#  'benefited',
#  'outdo',
#  'mistreatment',
#  'isaac',
#  'stew',
#  'advertiser',
#  'ditch',
#  'lynching',
#  'descend',
#  'karma',
#  'lacey',
#  'noises',
#  'nickelodeon',
#  'pile',
#  'faintest',
#  'lightsaber',
#  'crates',
#  'essentials',
#  'aspects',
#  'sean',
#  'stolen',
#  'infrequently',
#  'adjacent',
#  'dotcom',
#  'temperamental',
#  'spoke',
#  'commit',
#  'mariner',
#  'onscreen',
#  'viscera',
#  'gladiators',
#  'humanoid',
#  'depth',
#  'dereks',
#  'realms',
#  'pops',
#  'lacrosses',
#  'mtvs',
#  'ms',
#  'scary',
#  'euliss',
#  'kingpin',
#  'flaw',
#  'clockwork',
#  'uneventful',
#  'wound',
#  'becky',
#  'fictionesque',
#  'modicum',
#  'ticket',
#  'railroad',
#  'bar',
#  'nntphub',
#  'pleased',
#  'desk',
#  'division',
#  'subpar',
#  'callously',
#  'gridlockd',
#  'emperors',
#  'sites',
#  'bio',
#  'eschews',
#  'offagain',
#  'commentary',
#  'fa',
#  'zenith',
#  'lifelike',
#  'livelier',
#  'doe',
#  'boosting',
#  'afflecks',
#  'ditto',
#  'esque',
#  'sickeningly',
#  'patrons',
#  'throws',
#  'caped',
#  'crooked',
#  'sucked',
#  'dire',
#  'mai',
#  'skipped',
#  'kruger',
#  'slashing',
#  'brogue',
#  'luxurious',
#  'insomniacs',
#  'piled',
#  'consistently',
#  'helium',
#  'irreverent',
#  'melodramas',
#  'competitor',
#  'bogart',
#  'olin',
#  'horizon',
#  'katharine',
#  'scarlett',
#  'babs',
#  'suprisingly',
#  'challenger',
#  'bigname',
#  'smiths',
#  'taciturn',
#  'quarter',
#  'blawp',
#  'audacity',
#  'controllers',
#  'dweeb',
#  'belief',
#  'nora',
#  'elm',
#  'ming',
#  'zach',
#  'bounced',
#  'hyper',
#  'transparent',
#  'duguays',
#  'richmond',
#  'matrimony',
#  'hushed',
#  'persay',
#  'bruces',
#  'lem',
#  'awardwinning',
#  'immeasurably',
#  'uncertain',
#  'innocence',
#  'utilizes',
#  'juggernaut',
#  'closure',
#  'inconsistent',
#  'scares',
#  'dutiful',
#  'creepiest',
#  'already',
#  'livestock',
#  'seller',
#  'heads',
#  'chamberlain',
#  'sectors',
#  'food',
#  'copy',
#  'greyhound',
#  'slater',
#  'sequence',
#  'niccols',
#  'huge',
#  'extracting',
#  'sinister',
#  'orser',
#  'reggae',
#  'showtime',
#  'smack',
#  'acquaintances',
#  'comeuppance',
#  'blond',
#  'three',
#  'machineguns',
#  'parrs',
#  'tristar',
#  'momentum',
#  'charmer',
#  'pads',
#  'rears',
#  'highflying',
#  'relegated',
#  'skyscrapers',
#  'orthodox',
#  'ore',
#  'muriels',
#  'paced',
#  'azrael',
#  'larry',
#  'combative',
#  'yglesias',
#  'dealer',
#  'helps',
#  'pongo',
#  'multiple',
#  'waltz',
#  'ebert',
#  'scroll',
#  'rudnicks',
#  'spielbergs',
#  'vocation',
#  'bombshell',
#  'students',
#  'convicted',
#  'tangential',
#  'yeoh',
#  'weathers',
#  'kassovitz',
#  'gunpoint',
#  'niebaum',
#  'haddad',
#  'buster',
#  'irrelevant',
#  'military',
#  'night',
#  'liman',
#  'resulted',
#  'preoccupation',
#  'probation',
#  'charging',
#  'admittingly',
#  'seasoned',
#  'permutations',
#  'elevated',
#  'grateful',
#  'potentially',
#  'associate',
#  'chuck',
#  'ratty',
#  'racer',
#  'jailbreak',
#  'cuss',
#  'julias',
#  'illicit',
#  'recounting',
#  'thatll',
#  'bannen',
#  'preconceived',
#  'underworld',
#  'edtv',
#  'vaudeville',
#  'jogs',
#  'noodle',
#  'blethyn',
#  'question',
#  'dissection',
#  'beside',
#  'hidden',
#  'confuses',
#  'institutes',
#  'passions',
#  'boarded',
#  'obscenities',
#  'gravesite',
#  'marketable',
#  'bumbling',
#  'emmerich',
#  'enduring',
#  'incorporate',
#  'leezerd',
#  'otis',
#  'extremely',
#  'skywalker',
#  'thud',
#  'leaving',
#  'workplaces',
#  'kewl',
#  'extended',
#  'visage',
#  'decapitating',
#  'purge',
#  'scots',
#  'atlantic',
#  'hyperdrive',
#  'wary',
#  'papers',
#  'dreamer',
#  'education',
#  'meat',
#  'murdering',
#  'befitting',
#  'actor',
#  'footage',
#  'ohara',
#  'scattered',
#  'brits',
#  'speech',
#  'dry',
#  'impromptu',
#  'immune',
#  'shoulders',
#  'hobby',
#  'pidgeon',
#  'polley',
#  'universally',
#  'disappearances',
#  'welldesigned',
#  'woodman',
#  'graduation',
#  'shalhoub',
#  'ichabod',
#  'interspersed',
#  'grief',
#  'cinematically',
#  'allie',
#  'storyline',
#  'describes',
#  'hoggetts',
#  'loopy',
#  'newbie',
#  'bon',
#  'minimum',
#  'iced',
#  'rewatch',
#  'epic',
#  'embodied',
#  'geena',
#  'hyperactive',
#  'preserved',
#  'cecil',
#  'benton',
#  'protruding',
#  'napkin',
#  'preschool',
#  'degrees',
#  'purchase',
#  'worse',
#  'flesh',
#  'dreams',
#  'tranquility',
#  'aging',
#  'katanga',
#  'exterminate',
#  'bening',
#  'negated',
#  'schtick',
#  'ruined',
#  'traits',
#  'riddler',
#  'shandlings',
#  'blanchetts',
#  'weed',
#  'ellens',
#  'thinking',
#  'heresy',
#  'reappeared',
#  'har',
#  'snowy',
#  'inquisitive',
#  'latters',
#  'gist',
#  'intentionally',
#  'airwolf',
#  'kicker',
#  'drags',
#  'advisor',
#  'repeated',
#  'oneroom',
#  'assistants',
#  'ziggy',
#  'riotous',
#  'jeb',
#  'racism',
#  'boiled',
#  'avenues',
#  'talk',
#  'clamor',
#  'wronged',
#  'crafted',
#  'cranked',
#  'censors',
#  'moving',
#  'saucy',
#  'paymer',
#  'apologize',
#  'placements',
#  'nomi',
#  'illness',
#  'absences',
#  'explosive',
#  'dansons',
#  'ione',
#  'cook',
#  'stendhal',
#  'chopsticks',
#  'finished',
#  'itchy',
#  'screeching',
#  'repeats',
#  'slo',
#  'butthead',
#  'hairy',
#  'goddamned',
#  'rages',
#  'engrossing',
#  'beresfords',
#  'frenchmen',
#  'irritating',
#  'dance',
#  'homophobe',
#  'preface',
#  'hur',
#  'resides',
#  'advice',
#  'unforced',
#  'babies',
#  'setup',
#  'versus',
#  'mellow',
#  'achieved',
#  'accompanying',
#  'indication',
#  'chore',
#  'effectively',
#  'tend',
#  'dreamworkss',
#  'parable',
#  'roebuck',
#  'tanning',
#  'preposterously',
#  'mocked',
#  'hewitts',
#  'pyrotechnics',
#  'sneaking',
#  'harlem',
#  'discover',
#  'insular',
#  'hiroshima',
#  'individual',
#  'interpretation',
#  'beautiful',
#  'marian',
#  'depend',
#  'comparable',
#  'scaffolding',
#  'drink',
#  'malroux',
#  'gecko',
#  'coopers',
#  'satans',
#  'selfish',
#  'glib',
#  'oprah',
#  'deniro',
#  'cappie',
#  'freeman',
#  'partake',
#  'russ',
#  'refuge',
#  'enjoying',
#  'soso',
#  'isolation',
#  'speedy',
#  'titus',
#  'whitehaired',
#  'really',
#  'wonie',
#  'tricky',
#  'alessa',
#  'goodness',
#  'decreed',
#  'thompson',
#  'ronald',
#  'cabaret',
#  'amorality',
#  'goodbye',
#  'weiss',
#  'turned',
#  'theyve',
#  'pollack',
#  'shaved',
#  'maniacal',
#  'davidson',
#  'swoosie',
#  'philosophers',
#  ...}

# %%
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab)
# summarize what we have
print(len(positive_lines), len(negative_lines))

# %% [markdown]
# ## Tokenizer

# %%
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = positive_lines + negative_lines
tokenizer.fit_on_texts(docs)

# %%
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
Xtrain.shape
# Out:
# (3429, 25783)

# %%
print(len(docs[0]))
docs[0]
# Out:
# 2867
# 'assume nothing phrase perhaps one used first impressions rumors hardly ever seem phrase especially goes oscar novak architect main focus three tango delightful funny romantic comedy assumptions novak matthew perry shy clumsy chicago based architect along openly gay partner peter steinberg oliver platt fights projects day day one job restoring popular building charles newman dylan mcdermott rich wellknown businessman charles immediately takes liking oscar enjoys personality sense humor seeing oscar someone could trust charles asks watch girlfriend unpredictable adventurous girl named amy post neve campbell makes living blowing glass charles wants know talks goes point make sure shes seeing someone else course oscar gladly takes job meets amy art show sparks fly two get go oscar feels found one meant content idea amy well another popular phrase good things must come end stays true oscar well charles walks amy oscar drink one night oscar amy become great friends doesnt seem mind thinks oscar gay hes afraid share either oscar stands shock words swear werent gay oscar id kill muttered flamboyantly charles mouth word spreads instantly town oscar come supposed tell everyone isnt one would immediately think would deny fact numerous occurrences come oscar result fact denies fact could lose job charles matthew perry doesnt escape character chandler already classic comedy friends oscar novak chandler clueless shy sensitive nonetheless perry hilarious shows handle drama obviously character suffers quite bit wonderful see neve campbell outside horror movie star scream upcoming scream handles comedy superbly voice smile personality perfect romantic comedies stay genre neve neve delightful conflicted character feels love oscar knows based rumors gay usual campbell likable likable character unlike two leads dylan mcdermott flat dialogue never convincing character present mcdermott sets dull tone scene horrible acting stick drama practice dylan major weak spot three tango direction damon originality technique used whatsoever three tango lucky script edgy perry campbell wonderful comedy else film would disaster plain boring look three tango film done many times plot suspiciously close object affection plot never completed well three tangos script written rodney patrick vaccaro mckenna fun fast funny delivering original hilarious gay jokes run mill material certain dialogue characters always keeps smiling unlike last summers south park bigger longer uncut three tango comedy gay element crude vulgar script wise take route gays cant dont think anyway offended light playful comedy prove gay couple audience laughing constantly three tangos climax hilarious clever scene pure irony based outcome identity comedies three tango gem bottom line three tango light sharp snappy romantic comedy superb ending great stars one better romantic comedies'

# %%
docs = negative_lines + positive_lines
# encode training data set
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')
ytest = np.array([0 for _ in range(100)] + [1 for _ in range(100)])

# %%
docs[0]
# Out:
# 'bad bad bad one word seems pretty much sums beyond valley dolls summary isnt enough ta ta ta still havent got point director russ meyers predilection casting attractive large breasted women ultimately expose aforementioned areas really one reason recommend even taking look movie fact cowritten famed film critic roger ebert also responsible screenplay watching movie never able sit another one reviews gives movie thumbs bad writing straight face movie stinks loud quite frankly movie deserves parts bad almost funny im giving maybe generous right opening credits knew bomb hands way credits actually shot distracting first scene see includes big breasted young woman chased guy nazi uniform absolutely idea hell happening get explained later soon first scene cut completely unrelated scene honest sat movie mesmerized incredibly awful actually forgot seemingly place opening popped later film quality writing rest film wouldnt surprised opening never explained movie ask like really matters ok goes band headed kelly macnamara dolly reed friends go hollywood try gain foothold music industry manage find success due much hooters anything else sure wasnt brutally bad singing voices movie chronicles lives change worse pressures fame get everything big egos booze drugs free flowing sex sends downward spiral couple idiotic subplots thrown good measure fame one pretty much sums thing creative standpoint nothing redeeming obsession big russ meyer seemed dialogue incredibly bad literally funny parts mr ebert generously thrown hey man dig time favorite happening freaks ask lines like go wrong ebert tried inject many big words possible dialogue maybe thought would make movie seem smarter dont know big words world wouldnt able disguise bad writing even worse acting wretched dialogue goes along well wretched quality everything else movie ive seen home movies directed better meyer managed turkey fact one scene one van driving hollywood make fortunes really question meyer editors suffered serious head injuries add directing writing music movie almost got check sound system see broken pile crap speakers cast first lets start david played harris manager band got looking guy ever set foot front motion picture camera sadly acting doesnt come close making looks following along point shouldnt surprise meyers stable well endowed girls also benefit fairly attractive go along assets dolly reed plays kelly leader band surprise cast cup size talents yes loose shirt times display impressive talents sadly ass almost large chest hey sexist movie im writing sexist review former playboy playmate cynthia myers fairly small role casey one band members goes along rest idiotic thinking movie meyer casts gorgeous playmate rack kill obviously acting talent nude scenes biggest disappointment sure russ time get artsy throw well placed shadows side fun lesbo scene sound like im writing review porn magazine hey ill admit reason actually managed sit damn movie catch look cynthia myers naked since huge disappointment pretty much wasted two hours life turkey thing say movie stay away unless course want feel good knowing even pulitzer prize winning film critic like roger ebert screwed least life thinking checking double ds better nude cynthia myers pictures internet movie avoided costs even better idea might require video stores place warning box beyond valley dolls beware movie extremely common sense proceed extreme caution'

# %%
# load all docs in a directory
def process_docs(directory, vocab, is_trian):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if is_trian and filename.startswith('cv9'):
            continue
        if not is_trian and not filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# %%
# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, True)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, True)
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = negative_lines + positive_lines
tokenizer.fit_on_texts(docs)
# encode training data set
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
ytrain = np.array([0 for _ in range(900)] + [1 for _ in range(900)])
 
# load all test reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, False)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, False)
#positive_lines = process_docs('txt_sentoken/pos', vocab, False)
#negative_lines = process_docs('txt_sentoken/neg', vocab, False)
docs = negative_lines + positive_lines
# encode training data set
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')
ytest = np.array([0 for _ in range(100)] + [1 for _ in range(100)])

# %% [markdown]
# ## Creation Model

# %%
n_words = Xtest.shape[1]
# define network
model = Sequential()
model.add(Dense(50, input_shape=(n_words,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, ytrain, epochs=50, verbose=2)
# evaluate
loss, acc = model.evaluate(Xtest, ytest, verbose=0)
#print('Test Accuracy: %f' % (acc*100))
# Out:
# Epoch 1/50
# 2022-04-29 14:48:44.086716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.6916 - accuracy: 0.5167 - 695ms/epoch - 12ms/step
# Epoch 2/50
# 57/57 - 1s - loss: 0.6821 - accuracy: 0.5778 - 505ms/epoch - 9ms/step
# Epoch 3/50
# 57/57 - 1s - loss: 0.6653 - accuracy: 0.7028 - 507ms/epoch - 9ms/step
# Epoch 4/50
# 57/57 - 0s - loss: 0.6388 - accuracy: 0.7839 - 485ms/epoch - 9ms/step
# Epoch 5/50
# 57/57 - 1s - loss: 0.6039 - accuracy: 0.8850 - 526ms/epoch - 9ms/step
# Epoch 6/50
# 57/57 - 1s - loss: 0.5646 - accuracy: 0.9311 - 505ms/epoch - 9ms/step
# Epoch 7/50
# 57/57 - 0s - loss: 0.5208 - accuracy: 0.9372 - 491ms/epoch - 9ms/step
# Epoch 8/50
# 57/57 - 0s - loss: 0.4770 - accuracy: 0.9561 - 497ms/epoch - 9ms/step
# Epoch 9/50
# 57/57 - 0s - loss: 0.4333 - accuracy: 0.9639 - 492ms/epoch - 9ms/step
# Epoch 10/50
# 57/57 - 0s - loss: 0.3928 - accuracy: 0.9694 - 487ms/epoch - 9ms/step
# Epoch 11/50
# 57/57 - 0s - loss: 0.3535 - accuracy: 0.9761 - 483ms/epoch - 8ms/step
# Epoch 12/50
# 57/57 - 0s - loss: 0.3191 - accuracy: 0.9794 - 477ms/epoch - 8ms/step
# Epoch 13/50
# 57/57 - 0s - loss: 0.2865 - accuracy: 0.9828 - 489ms/epoch - 9ms/step
# Epoch 14/50
# 57/57 - 0s - loss: 0.2578 - accuracy: 0.9878 - 491ms/epoch - 9ms/step
# Epoch 15/50
# 57/57 - 0s - loss: 0.2321 - accuracy: 0.9906 - 494ms/epoch - 9ms/step
# Epoch 16/50
# 57/57 - 0s - loss: 0.2093 - accuracy: 0.9928 - 491ms/epoch - 9ms/step
# Epoch 17/50
# 57/57 - 0s - loss: 0.1891 - accuracy: 0.9933 - 488ms/epoch - 9ms/step
# Epoch 18/50
# 57/57 - 0s - loss: 0.1715 - accuracy: 0.9939 - 488ms/epoch - 9ms/step
# Epoch 19/50
# 57/57 - 0s - loss: 0.1548 - accuracy: 0.9939 - 474ms/epoch - 8ms/step
# Epoch 20/50
# 57/57 - 0s - loss: 0.1405 - accuracy: 0.9956 - 485ms/epoch - 9ms/step
# Epoch 21/50
# 57/57 - 0s - loss: 0.1273 - accuracy: 0.9967 - 484ms/epoch - 8ms/step
# Epoch 22/50
# 57/57 - 1s - loss: 0.1159 - accuracy: 0.9972 - 501ms/epoch - 9ms/step
# Epoch 23/50
# 57/57 - 1s - loss: 0.1056 - accuracy: 0.9983 - 516ms/epoch - 9ms/step
# Epoch 24/50
# 57/57 - 1s - loss: 0.0967 - accuracy: 0.9983 - 529ms/epoch - 9ms/step
# Epoch 25/50
# 57/57 - 1s - loss: 0.0884 - accuracy: 0.9983 - 526ms/epoch - 9ms/step
# Epoch 26/50
# 57/57 - 0s - loss: 0.0810 - accuracy: 0.9994 - 489ms/epoch - 9ms/step
# Epoch 27/50
# 57/57 - 0s - loss: 0.0742 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 28/50
# 57/57 - 0s - loss: 0.0684 - accuracy: 1.0000 - 490ms/epoch - 9ms/step
# Epoch 29/50
# 57/57 - 0s - loss: 0.0627 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 30/50
# 57/57 - 1s - loss: 0.0579 - accuracy: 1.0000 - 501ms/epoch - 9ms/step
# Epoch 31/50
# 57/57 - 0s - loss: 0.0535 - accuracy: 1.0000 - 490ms/epoch - 9ms/step
# Epoch 32/50
# 57/57 - 1s - loss: 0.0494 - accuracy: 1.0000 - 505ms/epoch - 9ms/step
# Epoch 33/50
# 57/57 - 0s - loss: 0.0457 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 34/50
# 57/57 - 1s - loss: 0.0424 - accuracy: 1.0000 - 512ms/epoch - 9ms/step
# Epoch 35/50
# 57/57 - 0s - loss: 0.0394 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 36/50
# 57/57 - 0s - loss: 0.0366 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 37/50
# 57/57 - 1s - loss: 0.0341 - accuracy: 1.0000 - 514ms/epoch - 9ms/step
# Epoch 38/50
# 57/57 - 1s - loss: 0.0318 - accuracy: 1.0000 - 517ms/epoch - 9ms/step
# Epoch 39/50
# 57/57 - 0s - loss: 0.0297 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 40/50
# 57/57 - 0s - loss: 0.0277 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 41/50
# 57/57 - 0s - loss: 0.0259 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 42/50
# 57/57 - 1s - loss: 0.0243 - accuracy: 1.0000 - 536ms/epoch - 9ms/step
# Epoch 43/50
# 57/57 - 1s - loss: 0.0228 - accuracy: 1.0000 - 526ms/epoch - 9ms/step
# Epoch 44/50
# 57/57 - 0s - loss: 0.0214 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 45/50
# 57/57 - 0s - loss: 0.0201 - accuracy: 1.0000 - 495ms/epoch - 9ms/step
# Epoch 46/50
# 57/57 - 1s - loss: 0.0189 - accuracy: 1.0000 - 503ms/epoch - 9ms/step
# Epoch 47/50
# 57/57 - 0s - loss: 0.0178 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 48/50
# 57/57 - 1s - loss: 0.0168 - accuracy: 1.0000 - 528ms/epoch - 9ms/step
# Epoch 49/50
# 57/57 - 1s - loss: 0.0159 - accuracy: 1.0000 - 522ms/epoch - 9ms/step
# Epoch 50/50
# 57/57 - 0s - loss: 0.0149 - accuracy: 1.0000 - 470ms/epoch - 8ms/step
# 2022-04-29 14:49:09.247786: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
matrix[0]
# Out:
# 'The'

# %%
matrix = ["The Matrix trilogy suggests that everyone has the individual responsibility to make the choice between the real world and an artificial world. Though Neo is the exemplar of free will, fate plays a large role in his adventure. Neo relies on the Oracle, and everything she says comes true in some way."]
print(len(matrix[0]))
matrix = clean_doc(matrix[0])
print(len(matrix))
token_matrix = [w for w in matrix if w in vocab]
token_matrix = ' '.join(token_matrix)
#token_matrix = tokenizer.texts_to_matrix(matrix, mode='freq')
token_matrix#.shape
# Out:
# 299
# 30
# 'trilogy suggests everyone individual responsibility make choice real world artificial world free fate plays large role adventure relies everything says comes true way'

# %%
token_matrix
# Out:
# 'trilogy suggests everyone individual responsibility make choice real world artificial world free fate plays large role adventure relies everything says comes true way'

# %%
tokenizer.texts_to_matrix(token_matrix, mode=True).shape
# Out:
# (166, 25783)

# %%
tokenizer.texts_to_matrix(matrix, mode="freq").shape
# Out:
# (30, 25783)

# %%
token_matrix.shape
# Out:
# (30, 25783)

# %%
tokens = clean_doc(doc)
# filter by vocab
tokens = [w for w in tokens if w in vocab]
return ' '.join(tokens)
# Out:
# 2022-04-29 15:10:48.545442: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# array([[5.0800914e-01],
#        [9.9926752e-01],
#        [9.9733752e-01],
#        [1.7148358e-03],
#        [9.9743420e-01],
#        [9.9606615e-01],
#        [8.4222972e-01],
#        [1.9156734e-09],
#        [9.9749988e-01],
#        [4.5795536e-01],
#        [9.9956447e-01],
#        [9.7678113e-01],
#        [9.9956447e-01],
#        [9.9900037e-01],
#        [9.9849796e-01],
#        [5.0800914e-01],
#        [4.5502695e-09],
#        [9.9403197e-01],
#        [9.9870598e-01],
#        [1.9736055e-04],
#        [9.9903381e-01],
#        [9.9968183e-01],
#        [9.9849796e-01],
#        [1.3564736e-01],
#        [5.0800914e-01],
#        [9.9904531e-01],
#        [1.1137142e-08],
#        [2.9517294e-05],
#        [9.9993956e-01],
#        [9.9879873e-01]], dtype=float32)

# %%
tokenizer.texts_to_matrix(train_docs, mode=mode)
# Out:
# (30, 25783)

# %%
from numpy import array
from string import punctuation
from os import listdir
from collections import Counter
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from pandas import DataFrame
from matplotlib import pyplot

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# turn a doc into clean tokens
def clean_doc(doc):
	# split into tokens by white space
	tokens = doc.split()
	# remove punctuation from each token
	table = str.maketrans('', '', punctuation)
	tokens = [w.translate(table) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# filter out stop words
	stop_words = set(stopwords.words('english'))
	tokens = [w for w in tokens if not w in stop_words]
	# filter out short tokens
	tokens = [word for word in tokens if len(word) > 1]
	return tokens

# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
	# load the doc
	doc = load_doc(filename)
	# clean doc
	tokens = clean_doc(doc)
	# filter by vocab
	tokens = [w for w in tokens if w in vocab]
	return ' '.join(tokens)

# load all docs in a directory
def process_docs(directory, vocab, is_trian):
	lines = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_trian and filename.startswith('cv9'):
			continue
		if not is_trian and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load and clean the doc
		line = doc_to_line(path, vocab)
		# add to list
		lines.append(line)
	return lines

# evaluate a neural network model
def evaluate_mode(Xtrain, ytrain, Xtest, ytest):
	scores = list()
	n_repeats = 30
	n_words = Xtest.shape[1]
	for i in range(n_repeats):
		# define network
		model = Sequential()
		model.add(Dense(50, input_shape=(n_words,), activation='relu'))
		model.add(Dense(1, activation='sigmoid'))
		# compile network
		model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
		# fit network
		model.fit(Xtrain, ytrain, epochs=50, verbose=2)
		# evaluate
		loss, acc = model.evaluate(Xtest, ytest, verbose=1)
		scores.append(acc)
		print('%d accuracy: %s' % ((i+1), acc))
	return scores

# prepare bag of words encoding of docs
def prepare_data(train_docs, test_docs, mode):
	# create the tokenizer
	tokenizer = Tokenizer()
	# fit the tokenizer on the documents
	tokenizer.fit_on_texts(train_docs)
	# encode training data set
	Xtrain = tokenizer.texts_to_matrix(train_docs, mode=mode)
	# encode training data set
	Xtest = tokenizer.texts_to_matrix(test_docs, mode=mode)
	return Xtrain, Xtest

# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, True)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, True)
train_docs = negative_lines + positive_lines
# load all test reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, False)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, False)
test_docs = negative_lines + positive_lines
# prepare labels
ytrain = array([0 for _ in range(900)] + [1 for _ in range(900)])
ytest = array([0 for _ in range(100)] + [1 for _ in range(100)])

modes = ['binary', 'count', 'tfidf', 'freq']
results = DataFrame()
for mode in modes:
	# prepare data for mode
	Xtrain, Xtest = prepare_data(train_docs, test_docs, mode)
	# evaluate model on data for mode
	results[mode] = evaluate_mode(Xtrain, ytrain, Xtest, ytest)
# summarize results
print(results.describe())
# plot results
results.boxplot()
pyplot.show()
# Out:
# Epoch 1/50
# 2022-04-29 15:22:15.918957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.4506 - accuracy: 0.7944 - 676ms/epoch - 12ms/step
# Epoch 2/50
# 57/57 - 0s - loss: 0.0490 - accuracy: 0.9933 - 489ms/epoch - 9ms/step
# Epoch 3/50
# 57/57 - 0s - loss: 0.0137 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 4/50
# 57/57 - 0s - loss: 0.0069 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 5/50
# 57/57 - 0s - loss: 0.0041 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 6/50
# 57/57 - 0s - loss: 0.0026 - accuracy: 1.0000 - 492ms/epoch - 9ms/step
# Epoch 7/50
# 57/57 - 0s - loss: 0.0018 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 8/50
# 57/57 - 0s - loss: 0.0013 - accuracy: 1.0000 - 477ms/epoch - 8ms/step
# Epoch 9/50
# 57/57 - 0s - loss: 9.2238e-04 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 10/50
# 57/57 - 0s - loss: 7.1727e-04 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 11/50
# 57/57 - 0s - loss: 5.6849e-04 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 12/50
# 57/57 - 1s - loss: 4.5763e-04 - accuracy: 1.0000 - 504ms/epoch - 9ms/step
# Epoch 13/50
# 57/57 - 1s - loss: 3.7640e-04 - accuracy: 1.0000 - 510ms/epoch - 9ms/step
# Epoch 14/50
# 57/57 - 0s - loss: 3.1208e-04 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 15/50
# 57/57 - 0s - loss: 2.6193e-04 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 16/50
# 57/57 - 0s - loss: 2.2244e-04 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 17/50
# 57/57 - 0s - loss: 1.9058e-04 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 18/50
# 57/57 - 0s - loss: 1.6504e-04 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 19/50
# 57/57 - 0s - loss: 1.4368e-04 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 20/50
# 57/57 - 1s - loss: 1.2635e-04 - accuracy: 1.0000 - 517ms/epoch - 9ms/step
# Epoch 21/50
# 57/57 - 0s - loss: 1.1182e-04 - accuracy: 1.0000 - 494ms/epoch - 9ms/step
# Epoch 22/50
# 57/57 - 0s - loss: 9.9468e-05 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 23/50
# 57/57 - 0s - loss: 8.9073e-05 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 24/50
# 57/57 - 0s - loss: 8.0116e-05 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 25/50
# 57/57 - 0s - loss: 7.2256e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 26/50
# 57/57 - 0s - loss: 6.5580e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 27/50
# 57/57 - 0s - loss: 5.9782e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 28/50
# 57/57 - 0s - loss: 5.4635e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 29/50
# 57/57 - 0s - loss: 5.0193e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 30/50
# 57/57 - 0s - loss: 4.6140e-05 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 31/50
# 57/57 - 0s - loss: 4.2544e-05 - accuracy: 1.0000 - 476ms/epoch - 8ms/step
# Epoch 32/50
# 57/57 - 1s - loss: 3.9495e-05 - accuracy: 1.0000 - 511ms/epoch - 9ms/step
# Epoch 33/50
# 57/57 - 0s - loss: 3.6506e-05 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 34/50
# 57/57 - 0s - loss: 3.3940e-05 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 35/50
# 57/57 - 0s - loss: 3.1568e-05 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 36/50
# 57/57 - 0s - loss: 2.9495e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 37/50
# 57/57 - 0s - loss: 2.7574e-05 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 38/50
# 57/57 - 0s - loss: 2.5810e-05 - accuracy: 1.0000 - 476ms/epoch - 8ms/step
# Epoch 39/50
# 57/57 - 0s - loss: 2.4203e-05 - accuracy: 1.0000 - 493ms/epoch - 9ms/step
# Epoch 40/50
# 57/57 - 1s - loss: 2.2720e-05 - accuracy: 1.0000 - 543ms/epoch - 10ms/step
# Epoch 41/50
# 57/57 - 1s - loss: 2.1407e-05 - accuracy: 1.0000 - 527ms/epoch - 9ms/step
# Epoch 42/50
# 57/57 - 0s - loss: 2.0145e-05 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 43/50
# 57/57 - 1s - loss: 1.9101e-05 - accuracy: 1.0000 - 520ms/epoch - 9ms/step
# Epoch 44/50
# 57/57 - 1s - loss: 1.7933e-05 - accuracy: 1.0000 - 509ms/epoch - 9ms/step
# Epoch 45/50
# 57/57 - 0s - loss: 1.6962e-05 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 46/50
# 57/57 - 0s - loss: 1.6037e-05 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 47/50
# 57/57 - 0s - loss: 1.5192e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 48/50
# 57/57 - 0s - loss: 1.4411e-05 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 49/50
# 57/57 - 0s - loss: 1.3668e-05 - accuracy: 1.0000 - 491ms/epoch - 9ms/step
# Epoch 50/50
# 57/57 - 1s - loss: 1.2980e-05 - accuracy: 1.0000 - 521ms/epoch - 9ms/step
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2500 - accuracy: 0.9200
# 1 accuracy: 0.9199999570846558
# 2022-04-29 15:22:40.630569: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/50
# 2022-04-29 15:22:41.021068: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.4712 - accuracy: 0.7828 - 687ms/epoch - 12ms/step
# Epoch 2/50
# 57/57 - 0s - loss: 0.0577 - accuracy: 0.9950 - 483ms/epoch - 8ms/step
# Epoch 3/50
# 57/57 - 0s - loss: 0.0156 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 4/50
# 57/57 - 0s - loss: 0.0074 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 5/50
# 57/57 - 0s - loss: 0.0043 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 6/50
# 57/57 - 0s - loss: 0.0029 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 7/50
# 57/57 - 0s - loss: 0.0020 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 8/50
# 57/57 - 0s - loss: 0.0014 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 9/50
# 57/57 - 0s - loss: 9.8481e-04 - accuracy: 1.0000 - 474ms/epoch - 8ms/step
# Epoch 10/50
# 57/57 - 0s - loss: 7.2946e-04 - accuracy: 1.0000 - 474ms/epoch - 8ms/step
# Epoch 11/50
# 57/57 - 0s - loss: 5.5903e-04 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 12/50
# 57/57 - 0s - loss: 4.3156e-04 - accuracy: 1.0000 - 494ms/epoch - 9ms/step
# Epoch 13/50
# 57/57 - 0s - loss: 3.3470e-04 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 14/50
# 57/57 - 0s - loss: 2.6250e-04 - accuracy: 1.0000 - 491ms/epoch - 9ms/step
# Epoch 15/50
# 57/57 - 0s - loss: 2.1138e-04 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 16/50
# 57/57 - 0s - loss: 1.7277e-04 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 17/50
# 57/57 - 0s - loss: 1.4374e-04 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 18/50
# 57/57 - 0s - loss: 1.2099e-04 - accuracy: 1.0000 - 492ms/epoch - 9ms/step
# Epoch 19/50
# 57/57 - 0s - loss: 1.0346e-04 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 20/50
# 57/57 - 0s - loss: 8.9205e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 21/50
# 57/57 - 1s - loss: 7.7771e-05 - accuracy: 1.0000 - 502ms/epoch - 9ms/step
# Epoch 22/50
# 57/57 - 0s - loss: 6.8967e-05 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 23/50
# 57/57 - 0s - loss: 6.0689e-05 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 24/50
# 57/57 - 0s - loss: 5.4210e-05 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 25/50
# 57/57 - 0s - loss: 4.8656e-05 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 26/50
# 57/57 - 0s - loss: 4.3885e-05 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 27/50
# 57/57 - 0s - loss: 3.9808e-05 - accuracy: 1.0000 - 472ms/epoch - 8ms/step
# Epoch 28/50
# 57/57 - 0s - loss: 3.6317e-05 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 29/50
# 57/57 - 0s - loss: 3.3236e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 30/50
# 57/57 - 0s - loss: 3.0512e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 31/50
# 57/57 - 0s - loss: 2.8140e-05 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 32/50
# 57/57 - 0s - loss: 2.5906e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 33/50
# 57/57 - 0s - loss: 2.3954e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 34/50
# 57/57 - 0s - loss: 2.2213e-05 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 35/50
# 57/57 - 0s - loss: 2.0619e-05 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 36/50
# 57/57 - 0s - loss: 1.9107e-05 - accuracy: 1.0000 - 477ms/epoch - 8ms/step
# Epoch 37/50
# 57/57 - 0s - loss: 1.7775e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 38/50
# 57/57 - 1s - loss: 1.6563e-05 - accuracy: 1.0000 - 529ms/epoch - 9ms/step
# Epoch 39/50
# 57/57 - 1s - loss: 1.5525e-05 - accuracy: 1.0000 - 510ms/epoch - 9ms/step
# Epoch 40/50
# 57/57 - 0s - loss: 1.4499e-05 - accuracy: 1.0000 - 490ms/epoch - 9ms/step
# Epoch 41/50
# 57/57 - 0s - loss: 1.3587e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 42/50
# 57/57 - 0s - loss: 1.2757e-05 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 43/50
# 57/57 - 0s - loss: 1.2001e-05 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 44/50
# 57/57 - 0s - loss: 1.1284e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 45/50
# 57/57 - 0s - loss: 1.0657e-05 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 46/50
# 57/57 - 0s - loss: 1.0050e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 47/50
# 57/57 - 0s - loss: 9.5193e-06 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 48/50
# 57/57 - 1s - loss: 8.9997e-06 - accuracy: 1.0000 - 500ms/epoch - 9ms/step
# Epoch 49/50
# 57/57 - 0s - loss: 8.5198e-06 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 50/50
# 57/57 - 0s - loss: 8.0810e-06 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2902 - accuracy: 0.8800
# 2 accuracy: 0.8799999952316284
# 2022-04-29 15:23:05.504214: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/50
# 2022-04-29 15:23:05.794112: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.4620 - accuracy: 0.7861 - 660ms/epoch - 12ms/step
# Epoch 2/50
# 57/57 - 0s - loss: 0.0552 - accuracy: 0.9928 - 479ms/epoch - 8ms/step
# Epoch 3/50
# 57/57 - 0s - loss: 0.0159 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 4/50
# 57/57 - 0s - loss: 0.0077 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 5/50
# 57/57 - 0s - loss: 0.0045 - accuracy: 1.0000 - 475ms/epoch - 8ms/step
# Epoch 6/50
# 57/57 - 0s - loss: 0.0027 - accuracy: 1.0000 - 471ms/epoch - 8ms/step
# Epoch 7/50
# 57/57 - 0s - loss: 0.0018 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 8/50
# 57/57 - 0s - loss: 0.0013 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 9/50
# 57/57 - 0s - loss: 9.6775e-04 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 10/50
# 57/57 - 0s - loss: 7.4469e-04 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 11/50
# 57/57 - 0s - loss: 5.9340e-04 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 12/50
# 57/57 - 0s - loss: 4.8274e-04 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 13/50
# 57/57 - 1s - loss: 4.0137e-04 - accuracy: 1.0000 - 505ms/epoch - 9ms/step
# Epoch 14/50
# 57/57 - 0s - loss: 3.3860e-04 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 15/50
# 57/57 - 0s - loss: 2.9110e-04 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 16/50
# 57/57 - 0s - loss: 2.5013e-04 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 17/50
# 57/57 - 0s - loss: 2.1854e-04 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 18/50
# 57/57 - 0s - loss: 1.9176e-04 - accuracy: 1.0000 - 499ms/epoch - 9ms/step
# Epoch 19/50
# 57/57 - 0s - loss: 1.7066e-04 - accuracy: 1.0000 - 485ms/epoch - 9ms/step
# Epoch 20/50
# 57/57 - 0s - loss: 1.5150e-04 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 21/50
# 57/57 - 0s - loss: 1.3556e-04 - accuracy: 1.0000 - 492ms/epoch - 9ms/step
# Epoch 22/50
# 57/57 - 0s - loss: 1.2222e-04 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 23/50
# 57/57 - 0s - loss: 1.1057e-04 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 24/50
# 57/57 - 0s - loss: 1.0068e-04 - accuracy: 1.0000 - 496ms/epoch - 9ms/step
# Epoch 25/50
# 57/57 - 1s - loss: 9.1593e-05 - accuracy: 1.0000 - 546ms/epoch - 10ms/step
# Epoch 26/50
# 57/57 - 1s - loss: 8.3887e-05 - accuracy: 1.0000 - 526ms/epoch - 9ms/step
# Epoch 27/50
# 57/57 - 0s - loss: 7.7147e-05 - accuracy: 1.0000 - 491ms/epoch - 9ms/step
# Epoch 28/50
# 57/57 - 0s - loss: 7.0972e-05 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 29/50
# 57/57 - 0s - loss: 6.5585e-05 - accuracy: 1.0000 - 497ms/epoch - 9ms/step
# Epoch 30/50
# 57/57 - 0s - loss: 6.0660e-05 - accuracy: 1.0000 - 476ms/epoch - 8ms/step
# Epoch 31/50
# 57/57 - 1s - loss: 5.6348e-05 - accuracy: 1.0000 - 515ms/epoch - 9ms/step
# Epoch 32/50
# 57/57 - 0s - loss: 5.2375e-05 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 33/50
# 57/57 - 1s - loss: 4.8915e-05 - accuracy: 1.0000 - 503ms/epoch - 9ms/step
# Epoch 34/50
# 57/57 - 0s - loss: 4.5621e-05 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 35/50
# 57/57 - 0s - loss: 4.2720e-05 - accuracy: 1.0000 - 483ms/epoch - 8ms/step
# Epoch 36/50
# 57/57 - 0s - loss: 4.0002e-05 - accuracy: 1.0000 - 489ms/epoch - 9ms/step
# Epoch 37/50
# 57/57 - 0s - loss: 3.7502e-05 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 38/50
# 57/57 - 0s - loss: 3.5222e-05 - accuracy: 1.0000 - 488ms/epoch - 9ms/step
# Epoch 39/50
# 57/57 - 1s - loss: 3.3132e-05 - accuracy: 1.0000 - 516ms/epoch - 9ms/step
# Epoch 40/50
# 57/57 - 1s - loss: 3.1195e-05 - accuracy: 1.0000 - 500ms/epoch - 9ms/step
# Epoch 41/50
# 57/57 - 0s - loss: 2.9400e-05 - accuracy: 1.0000 - 487ms/epoch - 9ms/step
# Epoch 42/50
# 57/57 - 0s - loss: 2.7737e-05 - accuracy: 1.0000 - 495ms/epoch - 9ms/step
# Epoch 43/50
# 57/57 - 1s - loss: 2.6223e-05 - accuracy: 1.0000 - 537ms/epoch - 9ms/step
# Epoch 44/50
# 57/57 - 0s - loss: 2.4785e-05 - accuracy: 1.0000 - 492ms/epoch - 9ms/step
# Epoch 45/50
# 57/57 - 0s - loss: 2.3461e-05 - accuracy: 1.0000 - 495ms/epoch - 9ms/step
# Epoch 46/50
# 57/57 - 0s - loss: 2.2221e-05 - accuracy: 1.0000 - 480ms/epoch - 8ms/step
# Epoch 47/50
# 57/57 - 0s - loss: 2.1075e-05 - accuracy: 1.0000 - 479ms/epoch - 8ms/step
# Epoch 48/50
# 57/57 - 0s - loss: 1.9992e-05 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 49/50
# 57/57 - 0s - loss: 1.8988e-05 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 50/50
# 57/57 - 0s - loss: 1.8059e-05 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2461 - accuracy: 0.9350
# 3 accuracy: 0.9350000023841858
# 2022-04-29 15:23:30.533334: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1/50
# 2022-04-29 15:23:30.849435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.4799 - accuracy: 0.7650 - 693ms/epoch - 12ms/step
# Epoch 2/50
# 57/57 - 0s - loss: 0.0636 - accuracy: 0.9939 - 488ms/epoch - 9ms/step
# Epoch 3/50
# 57/57 - 0s - loss: 0.0177 - accuracy: 1.0000 - 486ms/epoch - 9ms/step
# Epoch 4/50
# 57/57 - 0s - loss: 0.0077 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 5/50
# 57/57 - 0s - loss: 0.0041 - accuracy: 1.0000 - 482ms/epoch - 8ms/step
# Epoch 6/50
# 57/57 - 0s - loss: 0.0024 - accuracy: 1.0000 - 481ms/epoch - 8ms/step
# Epoch 7/50
# 57/57 - 0s - loss: 0.0015 - accuracy: 1.0000 - 478ms/epoch - 8ms/step
# Epoch 8/50
# 57/57 - 1s - loss: 0.0010 - accuracy: 1.0000 - 544ms/epoch - 10ms/step
# Epoch 9/50
# 57/57 - 1s - loss: 7.5536e-04 - accuracy: 1.0000 - 567ms/epoch - 10ms/step
# Epoch 10/50
# 57/57 - 1s - loss: 5.6574e-04 - accuracy: 1.0000 - 515ms/epoch - 9ms/step
# Epoch 11/50
# 57/57 - 1s - loss: 4.3562e-04 - accuracy: 1.0000 - 535ms/epoch - 9ms/step
# Epoch 12/50
# 57/57 - 0s - loss: 3.4067e-04 - accuracy: 1.0000 - 484ms/epoch - 8ms/step
# Epoch 13/50
# 57/57 - 1s - loss: 2.7141e-04 - accuracy: 1.0000 - 511ms/epoch - 9ms/step
# Epoch 14/50
# 57/57 - 0s - loss: 2.2019e-04 - accuracy: 1.0000 - 499ms/epoch - 9ms/step
# Epoch 15/50
# 57/57 - 1s - loss: 1.8266e-04 - accuracy: 1.0000 - 507ms/epoch - 9ms/step
# Epoch 16/50
# 57/57 - 0s - loss: 1.5437e-04 - accuracy: 1.0000 - 495ms/epoch - 9ms/step
# Epoch 17/50
# 57/57 - 1s - loss: 1.3212e-04 - accuracy: 1.0000 - 520ms/epoch - 9ms/step
# Epoch 18/50
# 57/57 - 0s - loss: 1.1444e-04 - accuracy: 1.0000 - 496ms/epoch - 9ms/step
# Epoch 19/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y8/78p5qgm10gbbfy4w6ysjrgt40000gn/T/ipykernel_481/893200194.py in <module>
#     120         Xtrain, Xtest = prepare_data(train_docs, test_docs, mode)
#     121         # evaluate model on data for mode
# --> 122         results[mode] = evaluate_mode(Xtrain, ytrain, Xtest, ytest)
#     123 # summarize results
#     124 print(results.describe())
#
# /var/folders/y8/78p5qgm10gbbfy4w6ysjrgt40000gn/T/ipykernel_481/893200194.py in evaluate_mode(Xtrain, ytrain, Xtest, ytest)
#      78                 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#      79                 # fit network
# ---> 80                 model.fit(Xtrain, ytrain, epochs=50, verbose=2)
#      81                 # evaluate
#      82                 loss, acc = model.evaluate(Xtest, ytest, verbose=1)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tf-conda-hugging/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
