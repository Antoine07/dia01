# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#Load-un-text" data-toc-modified-id="Load-un-text-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load un text</a></span></li><li><span><a href="#Clean" data-toc-modified-id="Clean-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Clean</a></span><ul class="toc-item"><li><span><a href="#Split-phrase-en-mots" data-toc-modified-id="Split-phrase-en-mots-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Split phrase en mots</a></span></li><li><span><a href="#Change-la-ponctuation-en-espace-vide" data-toc-modified-id="Change-la-ponctuation-en-espace-vide-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Change la ponctuation en espace vide</a></span></li><li><span><a href="#Enlève-les-tokens-numérique" data-toc-modified-id="Enlève-les-tokens-numérique-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Enlève les tokens numérique</a></span></li><li><span><a href="#Enlève-les-stop-words-(mots-vides)" data-toc-modified-id="Enlève-les-stop-words-(mots-vides)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Enlève les stop words (mots vides)</a></span></li><li><span><a href="#Enlève-les-mots-de-moins-d'une-lettre" data-toc-modified-id="Enlève-les-mots-de-moins-d'une-lettre-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Enlève les mots de moins d'une lettre</a></span></li><li><span><a href="#Fonction-pour-faire-tout-ça" data-toc-modified-id="Fonction-pour-faire-tout-ça-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Fonction pour faire tout ça</a></span></li></ul></li><li><span><a href="#Créer-un-vocabulaire" data-toc-modified-id="Créer-un-vocabulaire-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Créer un vocabulaire</a></span><ul class="toc-item"><li><span><a href="#Prendre-seulement-ceux-qui-ont-plus-de-2-occurences" data-toc-modified-id="Prendre-seulement-ceux-qui-ont-plus-de-2-occurences-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Prendre seulement ceux qui ont plus de 2 occurences</a></span></li><li><span><a href="#Enregistrer-le-vocabulaire" data-toc-modified-id="Enregistrer-le-vocabulaire-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Enregistrer le vocabulaire</a></span></li></ul></li><li><span><a href="#Convertir-to-bag-of-words" data-toc-modified-id="Convertir-to-bag-of-words-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Convertir to bag of words</a></span><ul class="toc-item"><li><span><a href="#Convertir-chaque-document-en-une-ligne-après-cleaning" data-toc-modified-id="Convertir-chaque-document-en-une-ligne-après-cleaning-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Convertir chaque document en une ligne après cleaning</a></span></li><li><span><a href="#Convertir-cette-ligne-en-représentation-de-bag-of-words" data-toc-modified-id="Convertir-cette-ligne-en-représentation-de-bag-of-words-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Convertir cette ligne en représentation de bag-of-words</a></span></li><li><span><a href="#Tokenisation-du-training-set" data-toc-modified-id="Tokenisation-du-training-set-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Tokenisation du training set</a></span></li><li><span><a href="#Tokenisation-du-test-set" data-toc-modified-id="Tokenisation-du-test-set-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Tokenisation du test set</a></span></li></ul></li><li><span><a href="#Creation-Model" data-toc-modified-id="Creation-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Creation Model</a></span><ul class="toc-item"><li><span><a href="#Test-sur-une-review-d'internet" data-toc-modified-id="Test-sur-une-review-d'internet-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Test sur une review d'internet</a></span></li></ul></li><li><span><a href="#Faire-la-comparaison-entre-les-méthodes" data-toc-modified-id="Faire-la-comparaison-entre-les-méthodes-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Faire la comparaison entre les méthodes</a></span><ul class="toc-item"><li><span><a href="#Prépare-la-fonction-pour-encoder-les-différents-modes" data-toc-modified-id="Prépare-la-fonction-pour-encoder-les-différents-modes-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Prépare la fonction pour encoder les différents modes</a></span></li><li><span><a href="#Prépare-la-fonction-pour-évaluer-les-différents-mode" data-toc-modified-id="Prépare-la-fonction-pour-évaluer-les-différents-mode-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Prépare la fonction pour évaluer les différents mode</a></span></li><li><span><a href="#Load-a-nouveau" data-toc-modified-id="Load-a-nouveau-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Load a nouveau</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Import

# %%
# MLP for the IMDB problem
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import string
import pandas as pd
import numpy as np
from string import punctuation
from os import listdir
from collections import Counter
from keras.preprocessing.text import Tokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/mc/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Load un text

# %%
filename = '/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos/cv000_29590.txt'
file = open(filename, 'r')
text = file.read()
print(len(text))
text
# Out:
# 4227
# ...

# %% [markdown]
# ## Clean
# ### Split phrase en mots

# %%
tokens = text.split()
print(tokens)
print(len(tokens))
# Out:
# ['films', 'adapted', 'from', 'comic', 'books', 'have', 'had', 'plenty', 'of', 'success', ',', 'whether', "they're", 'about', 'superheroes', '(', 'batman', ',', 'superman', ',', 'spawn', ')', ',', 'or', 'geared', 'toward', 'kids', '(', 'casper', ')', 'or', 'the', 'arthouse', 'crowd', '(', 'ghost', 'world', ')', ',', 'but', "there's", 'never', 'really', 'been', 'a', 'comic', 'book', 'like', 'from', 'hell', 'before', '.', 'for', 'starters', ',', 'it', 'was', 'created', 'by', 'alan', 'moore', '(', 'and', 'eddie', 'campbell', ')', ',', 'who', 'brought', 'the', 'medium', 'to', 'a', 'whole', 'new', 'level', 'in', 'the', 'mid', "'80s", 'with', 'a', '12-part', 'series', 'called', 'the', 'watchmen', '.', 'to', 'say', 'moore', 'and', 'campbell', 'thoroughly', 'researched', 'the', 'subject', 'of', 'jack', 'the', 'ripper', 'would', 'be', 'like', 'saying', 'michael', 'jackson', 'is', 'starting', 'to', 'look', 'a', 'little', 'odd', '.', 'the', 'book', '(', 'or', '"', 'graphic', 'novel', ',', '"', '
# ...

# %% [markdown]
# ### Change la ponctuation en espace vide

# %%
table = str.maketrans('', '', string.punctuation)
tokens = [w.translate(table) for w in tokens]
print(len(tokens))
#tokens
# Out:
# 802

# %% [markdown]
# ### Enlève les tokens numérique

# %%
tokens = [word for word in tokens if word.isalpha()]
print(len(tokens))
#tokens
# Out:
# 677

# %% [markdown]
# ### Enlève les stop words (mots vides)

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
tokens = [w for w in tokens if not w in stop_words]
#tokens
len(tokens)
# Out:
# 25767

# %% [markdown]
# ### Enlève les mots de moins d'une lettre

# %%
tokens = [word for word in tokens if len(word) > 1]
len(tokens)
# Out:
# 25767

# %% [markdown]
# ### Fonction pour faire tout ça

# %%
from nltk.corpus import stopwords
import string

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# turn a doc into clean tokens
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# load the document
filename = '/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos/cv000_29590.txt'
text = load_doc(filename)
tokens = clean_doc(text)
tokens
# Out:
# ['films',
#  'adapted',
#  'comic',
#  'books',
#  'plenty',
#  'success',
#  'whether',
#  'theyre',
#  'superheroes',
#  'batman',
#  'superman',
#  'spawn',
#  'geared',
#  'toward',
#  'kids',
#  'casper',
#  'arthouse',
#  'crowd',
#  'ghost',
#  'world',
#  'theres',
#  'never',
#  'really',
#  'comic',
#  'book',
#  'like',
#  'hell',
#  'starters',
#  'created',
#  'alan',
#  'moore',
#  'eddie',
#  'campbell',
#  'brought',
#  'medium',
#  'whole',
#  'new',
#  'level',
#  'mid',
#  'series',
#  'called',
#  'watchmen',
#  'say',
#  'moore',
#  'campbell',
#  'thoroughly',
#  'researched',
#  'subject',
#  'jack',
#  'ripper',
#  'would',
#  'like',
#  'saying',
#  'michael',
#  'jackson',
#  'starting',
#  'look',
#  'little',
#  'odd',
#  'book',
#  'graphic',
#  'novel',
#  'pages',
#  'long',
#  'includes',
#  'nearly',
#  'consist',
#  'nothing',
#  'footnotes',
#  'words',
#  'dont',
#  'dismiss',
#  'film',
#  'source',
#  'get',
#  'past',
#  'whole',
#  'comic',
# ...

# %% [markdown]
# ## Créer un vocabulaire
# ==> Contient le compte de tous les mots de toutes les datas

# %%
# define vocab
vocab = Counter()
vocab
# Out:
# Counter()

# %%
def add_doc_to_vocab(filename, vocab):
    # load doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # update counts
    vocab.update(tokens)

# load all docs in a directory
def process_docs(directory, vocab):
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # add doc to vocab
        add_doc_to_vocab(path, vocab)

# %%
vocab.update(['tata'])

# %%
# add all docs to vocab
process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab)
process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab)
# print the size of the vocab
print(len(vocab))
# print the top words in the vocab
print(vocab.most_common(50))
# Out:
# 44277
# [('film', 7983), ('one', 4946), ('movie', 4826), ('like', 3201), ('even', 2262), ('good', 2080), ('time', 2041), ('story', 1907), ('films', 1873), ('would', 1844), ('much', 1824), ('also', 1757), ('characters', 1735), ('get', 1724), ('character', 1703), ('two', 1643), ('first', 1588), ('see', 1557), ('way', 1515), ('well', 1511), ('make', 1418), ('really', 1407), ('little', 1351), ('life', 1334), ('plot', 1288), ('people', 1269), ('could', 1248), ('bad', 1248), ('scene', 1241), ('movies', 1238), ('never', 1201), ('best', 1179), ('new', 1140), ('scenes', 1135), ('man', 1131), ('many', 1130), ('doesnt', 1118), ('know', 1092), ('dont', 1086), ('hes', 1024), ('great', 1014), ('another', 992), ('action', 985), ('love', 977), ('us', 967), ('go', 952), ('director', 948), ('end', 946), ('something', 945), ('still', 936)]

# %% [markdown]
# ### Prendre seulement ceux qui ont plus de 2 occurences

# %%
min_occurance = 2
[k for k,c in vocab.items() if c >= min_occurance]
print(len(tokens))
# Out:
# 402

# %%
vocab.items()
# Out:
# dict_items([('tata', 1), ('assume', 41), ('nothing', 713), ('phrase', 27), ('perhaps', 418), ('one', 4946), ('used', 324), ('first', 1588), ('impressions', 6), ('rumors', 16), ('hardly', 102), ('ever', 661), ('seem', 523), ('especially', 410), ('goes', 584), ('oscar', 197), ('novak', 6), ('architect', 9), ('main', 355), ('focus', 135), ('three', 567), ('tango', 25), ('delightful', 52), ('funny', 738), ('romantic', 223), ('comedy', 738), ('assumptions', 4), ('matthew', 103), ('perry', 27), ('shy', 28), ('clumsy', 30), ('chicago', 45), ('based', 342), ('along', 476), ('openly', 12), ('gay', 97), ('partner', 100), ('peter', 230), ('steinberg', 2), ('oliver', 65), ('platt', 31), ('fights', 54), ('projects', 41), ('day', 535), ('job', 494), ('restoring', 4), ('popular', 172), ('building', 98), ('charles', 83), ('newman', 26), ('dylan', 19), ('mcdermott', 8), ('rich', 167), ('wellknown', 18), ('businessman', 26), ('immediately', 141), ('takes', 604), ('liking', 23), ('enjoys', 24), ('perso
# ...

# %%
# keep tokens with a min occurrence
min_occurane = 2
tokens = [k for k,c in vocab.items() if c >= min_occurane]
print(len(tokens))
# Out:
# 25767

# %% [markdown]
# ### Enregistrer le vocabulaire

# %%
# save list to file
def save_list(lines, filename):
    # convert lines to a single blob of text
    data = '\n'.join(lines)
    # open file
    file = open(filename, 'w')
    # write text
    file.write(data)
    # close file
    file.close()

# save tokens to a vocabulary file
save_list(tokens, 'vocab1.txt')

# %% [markdown]
# ## Convertir to bag of words
# Ici chaque document sera sous forme d'un vecteur de représentation de longueur du vocabulaire (22767 si on supprime les mots n'apparraissant unique plus de 2 fois)
# Il faut donc d'abords:
# - (1) Convertir chaque document en une ligne après cleaning
# - (2) Convertir cette ligne en représentation de bag-of-words
#
# ### Convertir chaque document en une ligne après cleaning

# %%
# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
    # load the doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [w for w in tokens if w in vocab]
    return ' '.join(tokens)


# load all docs in a directory
def process_docs(directory, vocab):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# %%
vocab_filename = 'vocab1.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
vocab
# Out:
# {'ips',
#  'swann',
#  'explorer',
#  'nexus',
#  'bondian',
#  'platinum',
#  'pretend',
#  'fairytale',
#  'looker',
#  'multinational',
#  'parasites',
#  'poppins',
#  'drawbridge',
#  'davidtz',
#  'amphetamines',
#  'count',
#  'crooning',
#  'workaholic',
#  'monthlong',
#  'allegory',
#  'kiefer',
#  'thickened',
#  'cad',
#  'tycoon',
#  'murray',
#  'franciss',
#  'whistle',
#  'bebe',
#  'feldmans',
#  'sincere',
#  'stooges',
#  'existenz',
#  'sizable',
#  'arrived',
#  'widowed',
#  'prodigies',
#  'movements',
#  'colors',
#  'festival',
#  'embarrassment',
#  'harrington',
#  'chandler',
#  'bareikis',
#  'glimmers',
#  'turner',
#  'dartagnans',
#  'eyes',
#  'supernatural',
#  'symbol',
#  'depressingly',
#  'compassionate',
#  'madden',
#  'ramifications',
#  'grimace',
#  'billie',
#  'catania',
#  'gases',
#  'mcgillis',
#  'blunders',
#  'stay',
#  'june',
#  'gilligans',
#  'ballistic',
#  'backtrack',
#  'eduardo',
#  'scholarly',
#  'dissatisfied',
# ...

# %%
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab)
# summarize what we have
print(len(positive_lines), len(negative_lines))
# Out:
# 900 900

# %% [markdown]
# ### Convertir cette ligne en représentation de bag-of-words
# Il est possibile d'utiliser l'API de Keras pour transformer les phrases en vecteurs. Il suffit simplement d'entraîner (fit) nos training review et d'indiquer le mode, il en existe plusieurs:
# - freq
# - count
# - tdif
# - binary

# %%
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = positive_lines + negative_lines
tokenizer.fit_on_texts(docs)

# %%
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')
Xtrain.shape#[0]
# Out:
# (1800, 25768)

# %% [markdown]
# Il faut modifier notre fonction process_docs afin qu'elle prenne en compte si nous sommes dans le training ou le test set. L'objectif est d'éviter le data leakage et d'obtenir des informations sur notre test set alors que l'on doit rester le plus naïf possible

# %%
# load all docs in a directory
def process_docs(directory, vocab, is_trian):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip any reviews in the test set
        if is_trian and filename.startswith('cv9'):
            continue
        if not is_trian and not filename.startswith('cv9'):
            continue
        # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# %% [markdown]
# ### Tokenisation du training set

# %%
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, True)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, True)
# create the tokenizer
tokenizer = Tokenizer()
# fit the tokenizer on the documents
docs = negative_lines + positive_lines
tokenizer.fit_on_texts(docs)
Xtrain = tokenizer.texts_to_matrix(docs, mode='freq')

# %% [markdown]
# ### Tokenisation du test set

# %%
# load all test reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, False)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, False)
docs = negative_lines + positive_lines
# encode training data set
Xtest = tokenizer.texts_to_matrix(docs, mode='freq')
print(Xtest.shape)
# Out:
# (200, 25768)

# %%
tokenizer.texts_to_matrix(docs, mode='freq').shape
# Out:
# (200, 25768)

# %% [markdown]
# ## Creation Model
# Il faut d'abords créer la target qui est assez facile 1 pour positive et 0 pour négative pour le training et test set

# %%
ytrain = np.array([0 for _ in range(900)] + [1 for _ in range(900)])
ytest = np.array([0 for _ in range(100)] + [1 for _ in range(100)])

# %%
n_words = Xtest.shape[1]
# define network
model = Sequential()
model.add(Dense(50, input_shape=(n_words,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, ytrain,  validation_data=(Xtest, ytest), epochs=50, verbose=2)
# evaluate
loss, acc = model.evaluate(Xtest, ytest, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Epoch 1/50
# 2022-05-29 12:36:58.520729: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.6920 - accuracy: 0.5683 - val_loss: 0.6897 - val_accuracy: 0.5550 - 1s/epoch - 20ms/step
# Epoch 2/50
# 2022-05-29 12:36:59.391655: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.6844 - accuracy: 0.7889 - val_loss: 0.6825 - val_accuracy: 0.7200 - 652ms/epoch - 11ms/step
# Epoch 3/50
# 57/57 - 1s - loss: 0.6695 - accuracy: 0.7439 - val_loss: 0.6698 - val_accuracy: 0.7850 - 625ms/epoch - 11ms/step
# Epoch 4/50
# 57/57 - 1s - loss: 0.6453 - accuracy: 0.9294 - val_loss: 0.6517 - val_accuracy: 0.8300 - 619ms/epoch - 11ms/step
# Epoch 5/50
# 57/57 - 1s - loss: 0.6140 - accuracy: 0.9233 - val_loss: 0.6300 - val_accuracy: 0.8400 - 612ms/epoch - 11ms/step
# Epoch 6/50
# ...

# %%
matrix = ["The Matrix trilogy suggests that everyone has the individual responsibility to make the choice between the real world and an artificial world. Though Neo is the exemplar of free will, fate plays a large role in his adventure. Neo relies on the Oracle, and everything she says comes true in some way."]
#matrix = ['The title of this noisy, stupid, totally boring bomb should really be “Hard Watch”—unless you’re willing to treat its avalanche of clichés as an invitation to an unintentional laugh-fest.']
print(matrix)
print(len(matrix[0]))
matrix = clean_doc(matrix[0])
print(len(matrix))
token_matrix = [w for w in matrix if w in vocab]
# Out:
# ['The Matrix trilogy suggests that everyone has the individual responsibility to make the choice between the real world and an artificial world. Though Neo is the exemplar of free will, fate plays a large role in his adventure. Neo relies on the Oracle, and everything she says comes true in some way.']
# 299
# 30

# %%
token_matrix = ' '.join(token_matrix)
np.array(token_matrix).shape
# Out:
# ()

# %%
token_matrix = [token_matrix, " "]
token_matrix
# Out:
# ['trilogy suggests everyone individual responsibility make choice real world artificial world free fate plays large role adventure relies everything says comes true way',
#  ' ']

# %% [markdown]
# ### Test sur une review d'internet

# %%
#matrix = ["The Matrix trilogy suggests that everyone has the individual responsibility to make the choice between the real world and an artificial world. Though Neo is the exemplar of free will, fate plays a large role in his adventure. Neo relies on the Oracle, and everything she says comes true in some way."]
matrix = ['The title of this noisy, stupid, totally boring bomb should really be “Hard Watch”—unless you’re willing to treat its avalanche of clichés as an invitation to an unintentional laugh-fest.']
print(matrix)
print(len(matrix[0]))
matrix = clean_doc(matrix[0])
print(len(matrix))
token_matrix = [w for w in matrix if w in vocab]
token_matrix = ' '.join(token_matrix)
token_matrix = [token_matrix]
token_matrix = tokenizer.texts_to_matrix(token_matrix, mode='freq')
token_matrix[0]
prediction = round(model.predict(token_matrix)[0,0])

print('The film is good? ', bool(prediction))
# Out:
# ['The title of this noisy, stupid, totally boring bomb should really be “Hard Watch”—unless you’re willing to treat its avalanche of clichés as an invitation to an unintentional laugh-fest.']
# 187
# 15
# The film is good?  False

# %% [markdown]
# ## Faire la comparaison entre les méthodes
# - Binary (chaque mot est présent ou absent 1, 0)
# - Count (compter le nombre de mots)
# - tfidf (fréquence du mot et les mots communs entre chaque documents sont pénalisé)
# - fréquence
#
# ### Prépare la fonction pour encoder les différents modes

# %%
# prepare bag of words encoding of docs
def prepare_data(train_docs, test_docs, mode):
    # create the tokenizer
    tokenizer = Tokenizer()
    # fit the tokenizer on the documents
    tokenizer.fit_on_texts(train_docs)
    # encode training data set
    Xtrain = tokenizer.texts_to_matrix(train_docs, mode=mode)
    # encode training data set
    Xtest = tokenizer.texts_to_matrix(test_docs, mode=mode)
    return Xtrain, Xtest

# %% [markdown]
# ### Prépare la fonction pour évaluer les différents mode

# %%
def evaluate_mode(Xtrain, ytrain, Xtest, ytest):
    scores = list()
    n_repeats = 30
    n_words = Xtest.shape[1]
    for i in range(n_repeats):
        # define network
        model = Sequential()
        model.add(Dense(50, input_shape=(n_words,), activation='relu'))
        model.add(Dense(1, activation='sigmoid'))
        # compile network
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        # fit network
        model.fit(Xtrain, ytrain, epochs=50, verbose=2)
        # evaluate
        loss, acc = model.evaluate(Xtest, ytest, verbose=0)
        scores.append(acc)
        print('%d accuracy: %s' % ((i+1), acc))
    return scores

# %% [markdown]
# ### Load a nouveau

# %%
# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# load all training reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, True)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, True)
train_docs = negative_lines + positive_lines
# load all test reviews
positive_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/pos', vocab, False)
negative_lines = process_docs('/Users/mc/Documents/Cours/review_polarity/txt_sentoken/neg', vocab, False)
test_docs = negative_lines + positive_lines
# prepare labels
ytrain = array([0 for _ in range(900)] + [1 for _ in range(900)])
ytest = array([0 for _ in range(100)] + [1 for _ in range(100)])

# %%
modes = ['binary', 'count', 'tfidf', 'freq']
results = pd.DataFrame()
for mode in modes:
    # prepare data for mode
    Xtrain, Xtest = prepare_data(train_docs, test_docs, mode)
    # evaluate model on data for mode
    results[mode] = evaluate_mode(Xtrain, ytrain, Xtest, ytest)
# Out:
# Epoch 1/50
# 2022-05-18 10:42:36.697926: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 57/57 - 1s - loss: 0.4735 - accuracy: 0.7728 - 720ms/epoch - 13ms/step
# Epoch 2/50
# 57/57 - 1s - loss: 0.0570 - accuracy: 0.9950 - 520ms/epoch - 9ms/step
# Epoch 3/50
# 57/57 - 1s - loss: 0.0147 - accuracy: 1.0000 - 511ms/epoch - 9ms/step
# Epoch 4/50
# 57/57 - 1s - loss: 0.0069 - accuracy: 1.0000 - 512ms/epoch - 9ms/step
# Epoch 5/50
# 57/57 - 1s - loss: 0.0037 - accuracy: 1.0000 - 538ms/epoch - 9ms/step
# Epoch 6/50
# 57/57 - 1s - loss: 0.0021 - accuracy: 1.0000 - 505ms/epoch - 9ms/step
# Epoch 7/50
# 57/57 - 1s - loss: 0.0013 - accuracy: 1.0000 - 500ms/epoch - 9ms/step
# Epoch 8/50
# 57/57 - 0s - loss: 8.0329e-04 - accuracy: 1.0000 - 492ms/epoch - 9ms/step
# Epoch 9/50
# 57/57 - 1s - loss: 5.3873e-04 - accuracy: 1.0000 - 500ms/epoch - 9ms/step
# Epoch 10/50
# ...

# %%
# summarize results
print(results.describe())
# plot results
results.boxplot()
plt.show()
# Out:
#           binary      count      tfidf       freq
# count  30.000000  30.000000  30.000000  30.000000
# mean    0.916000   0.890667   0.861000   0.908500
# std     0.008749   0.011198   0.013222   0.002675
# min     0.900000   0.855000   0.835000   0.905000
# 25%     0.910000   0.885000   0.851250   0.905000
# 50%     0.915000   0.890000   0.862500   0.910000
# 75%     0.920000   0.895000   0.870000   0.910000
# max     0.935000   0.910000   0.890000   0.915000
